# %%
import numpy as np
def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def relu(x):
    return np.maximum(0, x)


def softmax(x):
    if x.ndim == 2:
        x = x - x.max(axis=1, keepdims=True)
        x = np.exp(x)
        x /= x.sum(axis=1, keepdims=True)
    elif x.ndim == 1:
        x = x - np.max(x)
        x = np.exp(x) / np.sum(np.exp(x))

    return x


def cross_entropy_error(y, t):
    if y.ndim == 1:
        t = t.reshape(1, t.size)
        y = y.reshape(1, y.size)
        
    # 訓練資料為one-hot向量時，轉換成正解標籤的索引值
    if t.size == y.size:
        t = t.argmax(axis=1)
             
    batch_size = y.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), t] + 1e-7)) / batch_size

# %%
class MatMul:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.x = None

    def forward(self, x):
        W, = self.params
        out = np.dot(x, W)
        self.x = x
        return out

    def backward(self, dout):
        W, = self.params
        dx = np.dot(dout, W.T)
        dW = np.dot(self.x.T, dout)
        self.grads[0][...] = dW
        return dx


class Affine:
    def __init__(self, W, b):
        self.params = [W, b]
        self.grads = [np.zeros_like(W), np.zeros_like(b)]
        self.x = None

    def forward(self, x):
        W, b = self.params
        out = np.dot(x, W) + b
        self.x = x
        return out

    def backward(self, dout):
        W, b = self.params
        dx = np.dot(dout, W.T)
        dW = np.dot(self.x.T, dout)
        db = np.sum(dout, axis=0)

        self.grads[0][...] = dW
        self.grads[1][...] = db
        return dx


class Softmax:
    def __init__(self):
        self.params, self.grads = [], []
        self.out = None

    def forward(self, x):
        self.out = softmax(x)
        return self.out

    def backward(self, dout):
        dx = self.out * dout
        sumdx = np.sum(dx, axis=1, keepdims=True)
        dx -= self.out * sumdx
        return dx


class SoftmaxWithLoss:
    def __init__(self):
        self.params, self.grads = [], []
        self.y = None  # softmax的輸出
        self.t = None  # 訓練標籤

    def forward(self, x, t):
        self.t = t
        self.y = softmax(x)
        # 訓練標籤為one-hot向量時，轉換成正解標籤的索引值        if self.t.size == self.y.size:
        self.t = self.t.argmax(axis=1)

        loss = cross_entropy_error(self.y, self.t)
        return loss

    def backward(self, dout=1):
        batch_size = self.t.shape[0]

        dx = self.y.copy()
        dx[np.arange(batch_size), self.t] -= 1
        dx *= dout
        dx = dx / batch_size

        return dx


class Sigmoid:
    def __init__(self):
        self.params, self.grads = [], []
        self.out = None

    def forward(self, x):
        out = 1 / (1 + np.exp(-x))
        self.out = out
        return out

    def backward(self, dout):
        dx = dout * (1.0 - self.out) * self.out
        return dx


class SigmoidWithLoss:
    def __init__(self):
        self.params, self.grads = [], []
        self.loss = None
        self.y = None  # sigmoid的輸出
        self.t = None  # 訓練資料

    def forward(self, x, t):
        self.t = t
        self.y = 1 / (1 + np.exp(-x))

        self.loss = cross_entropy_error(np.c_[1 - self.y, self.y], self.t)

        return self.loss

    def backward(self, dout=1):
        batch_size = self.t.shape[0]

        dx = (self.y - self.t) * dout / batch_size
        return dx


class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.params, self.grads = [], []
        self.dropout_ratio = dropout_ratio
        self.mask = None

    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)

    def backward(self, dout):
        return dout * self.mask


class Embedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None

    def forward(self, idx):
        W, = self.params
        self.idx = idx
        out = W[idx]
        return out

    def backward(self, dout):
        dW, = self.grads
        dW[...] = 0
        np.add.at(dW, self.idx, dout)
        return None

# %%
np.random.randn(5, 3).astype('f')
# W_5*3
# Out:
# array([[ 1.1007979 ,  1.0549431 , -0.59907144],
#        [-0.52564275, -0.0291924 ,  0.31616652],
#        [-0.01521177, -0.68735325,  0.7135979 ],
#        [-0.12307957, -1.1603168 ,  0.3184487 ],
#        [ 1.921053  , -0.2800927 ,  0.9871168 ]], dtype=float32)

# %%
 V, H = 5, 3

# 初始化權重
W_in = 0.01 * np.random.randn(V, H).astype('f')
W_out = 0.01 * np.random.randn(H, V).astype('f')
        
# 產生各層
in_layer = MatMul(W_in)
out_layer = MatMul(W_out)
loss_layer1 = SoftmaxWithLoss()
loss_layer2 = SoftmaxWithLoss()
# 把全部的權重與梯度整合成清單
layers = [in_layer, out_layer]
params, grads = [], []
for layer in layers:
  params += layer.params
  print(params)
  grads += layer.grads
# Out:
# [array([[ 0.00493051,  0.00985003, -0.0036187 ],
#        [ 0.00179025,  0.00812375, -0.00123686],
#        [-0.00603372, -0.0089062 , -0.00135542],
#        [ 0.02474449,  0.00253233,  0.00257908],
#        [ 0.00485458, -0.01449288,  0.01247964]], dtype=float32)]
# [array([[ 0.00493051,  0.00985003, -0.0036187 ],
#        [ 0.00179025,  0.00812375, -0.00123686],
#        [-0.00603372, -0.0089062 , -0.00135542],
#        [ 0.02474449,  0.00253233,  0.00257908],
#        [ 0.00485458, -0.01449288,  0.01247964]], dtype=float32), array([[ 0.00180995, -0.00157237, -0.01733608,  0.01285063, -0.01532826],
#        [-0.0048878 ,  0.01086626, -0.0011619 ,  0.01270247, -0.00641222],
#        [-0.00579789, -0.00261871,  0.00228758, -0.00389237, -0.01314386]],
#       dtype=float32)]

# %% [markdown]
# #Skip Gram design

# %%
class SimpleSkipGram:
    def __init__(self, vocab_size, hidden_size):
        V, H = vocab_size, hidden_size

        # 初始化權重
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(H, V).astype('f')
        
        # 產生各層
        self.in_layer = MatMul(W_in)
        self.out_layer = MatMul(W_out)
        self.loss_layer1 = SoftmaxWithLoss()
        self.loss_layer2 = SoftmaxWithLoss()

        # 把全部的權重與梯度整合成清單
        layers = [self.in_layer, self.out_layer]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 在成員變數中，設定字詞的分式散表示
        self.word_vecs = W_in
    
    def forward(self, contexts, target):
        h = self.in_layer.forward(target)
        s = self.out_layer.forward(h)
        l1 = self.loss_layer1.forward(s, contexts[:, 0])
        l2 = self.loss_layer2.forward(s, contexts[:, 1])
        loss = l1 + l2
        return loss

    def backward(self, dout=1):
        dl1 = self.loss_layer1.backward(dout)
        dl2 = self.loss_layer2.backward(dout)
        ds = dl1 + dl2
        dh = self.out_layer.backward(ds)
        self.in_layer.backward(dh)
        return None

# %% [markdown]
# # TibaMe code

# %%
# util
# TibaMe code
import os
def preprocess(text):
    text = text.lower()
    text = text.replace('.', ' .')
    words = text.split(' ')

    word_to_id = {}
    id_to_word = {}
    for word in words:
        if word not in word_to_id:
            new_id = len(word_to_id)
            word_to_id[word] = new_id
            id_to_word[new_id] = word

    corpus = np.array([word_to_id[w] for w in words])

    return corpus, word_to_id, id_to_word




def convert_one_hot(corpus, vocab_size):
    '''
    轉換成one-hot編碼
    param corpus: 字詞ID清單（一維或二維NumPy陣列）
    param vocab_size: 語彙量
    return: one-hot編碼（二維或三為NumPy陣列）
    '''
    N = corpus.shape[0]

    if corpus.ndim == 1:
        one_hot = np.zeros((N, vocab_size), dtype=np.int32)
        for idx, word_id in enumerate(corpus):
            one_hot[idx, word_id] = 1

    elif corpus.ndim == 2:
        C = corpus.shape[1]
        one_hot = np.zeros((N, C, vocab_size), dtype=np.int32)
        for idx_0, word_ids in enumerate(corpus):
            for idx_1, word_id in enumerate(word_ids):
                one_hot[idx_0, idx_1, word_id] = 1

    return one_hot


def create_contexts_target(corpus, window_size=1):
    '''
    轉換成one-hot編碼
    param words: 字詞ID的NumPy陣列
    param vocab_size: 語彙量
    return: 轉換成one-hot編碼後的NumPy陣列
    '''
    target = corpus[window_size:-window_size]
    contexts = []

    for idx in range(window_size, len(corpus)-window_size):
        cs = []
        for t in range(-window_size, window_size + 1):
            if t == 0:
                continue
            cs.append(corpus[idx + t])
        contexts.append(cs)

    return np.array(contexts), np.array(target)


def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)

    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate

# %% [markdown]
# # TibaMe optimizer code

# %%
# optimizer
# 參考TibaMe optimizer code
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for i in range(len(params)):
            params[i] -= self.lr * grads[i]


class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
        
    def update(self, params, grads):
        if self.v is None:
            self.v = []
            for param in params:
                self.v.append(np.zeros_like(param))

        for i in range(len(params)):
            self.v[i] = self.momentum * self.v[i] - self.lr * grads[i]
            params[i] += self.v[i]


class Nesterov:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
        
    def update(self, params, grads):
        if self.v is None:
            self.v = []
            for param in params:
                self.v.append(np.zeros_like(param))

        for i in range(len(params)):
            self.v[i] *= self.momentum
            self.v[i] -= self.lr * grads[i]
            params[i] += self.momentum * self.momentum * self.v[i]
            params[i] -= (1 + self.momentum) * self.lr * grads[i]


class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = []
            for param in params:
                self.h.append(np.zeros_like(param))

        for i in range(len(params)):
            self.h[i] += grads[i] * grads[i]
            params[i] -= self.lr * grads[i] / (np.sqrt(self.h[i]) + 1e-7)


class RMSprop:
    def __init__(self, lr=0.01, decay_rate = 0.99):
        self.lr = lr
        self.decay_rate = decay_rate
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = []
            for param in params:
                self.h.append(np.zeros_like(param))

        for i in range(len(params)):
            self.h[i] *= self.decay_rate
            self.h[i] += (1 - self.decay_rate) * grads[i] * grads[i]
            params[i] -= self.lr * grads[i] / (np.sqrt(self.h[i]) + 1e-7)


class Adam:
    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.iter = 0
        self.m = None
        self.v = None
        
    def update(self, params, grads):
        if self.m is None:
            self.m, self.v = [], []
            for param in params:
                self.m.append(np.zeros_like(param))
                self.v.append(np.zeros_like(param))
        
        self.iter += 1
        lr_t = self.lr * np.sqrt(1.0 - self.beta2**self.iter) / (1.0 - self.beta1**self.iter)

        for i in range(len(params)):
            self.m[i] += (1 - self.beta1) * (grads[i] - self.m[i])
            self.v[i] += (1 - self.beta2) * (grads[i]**2 - self.v[i])
            
            params[i] -= lr_t * self.m[i] / (np.sqrt(self.v[i]) + 1e-7)

# %% [markdown]
# # TibaMe training code

# %%
import numpy
import time
import matplotlib.pyplot as plt

class Trainer:
    def __init__(self, model, optimizer):
        self.model = model
        self.optimizer = optimizer
        self.loss_list = []
        self.eval_interval = None
        self.current_epoch = 0

    def fit(self, x, t, max_epoch=10, batch_size=32, max_grad=None, eval_interval=30):
        data_size = len(x)
        max_iters = data_size // batch_size
        self.eval_interval = eval_interval
        model, optimizer = self.model, self.optimizer
        total_loss = 0
        loss_count = 0

        start_time = time.time()
        for epoch in range(max_epoch):
            # 資料洗牌
            idx = numpy.random.permutation(numpy.arange(data_size))
            x = x[idx]
            t = t[idx]

            for iters in range(max_iters):
                batch_x = x[iters*batch_size:(iters+1)*batch_size]
                batch_t = t[iters*batch_size:(iters+1)*batch_size]

                # 計算梯度，更新參數
                loss = model.forward(batch_x, batch_t)
                model.backward()
                params, grads = remove_duplicate(model.params, model.grads)  # 把共用的權重整合成一個
                if max_grad is not None:
                    clip_grads(grads, max_grad)
                optimizer.update(params, grads)
                total_loss += loss
                loss_count += 1

                # 評估
                if (eval_interval is not None) and (iters % eval_interval) == 0:
                    avg_loss = total_loss / loss_count
                    elapsed_time = time.time() - start_time
                    print('| epoch %d |  iter %d / %d | time %d[s] | loss %.2f'
                          % (self.current_epoch + 1, iters + 1, max_iters, elapsed_time, avg_loss))
                    self.loss_list.append(float(avg_loss))
                    total_loss, loss_count = 0, 0

            self.current_epoch += 1

    def plot(self, ylim=None):
        x = numpy.arange(len(self.loss_list))
        if ylim is not None:
            plt.ylim(*ylim)
        plt.plot(x, self.loss_list, label='train')
        plt.xlabel('iterations (x' + str(self.eval_interval) + ')')
        plt.ylabel('loss')
        plt.show()


class RnnlmTrainer:
    def __init__(self, model, optimizer):
        self.model = model
        self.optimizer = optimizer
        self.time_idx = None
        self.ppl_list = None
        self.eval_interval = None
        self.current_epoch = 0

    def get_batch(self, x, t, batch_size, time_size):
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')

        data_size = len(x)
        jump = data_size // batch_size
        offsets = [i * jump for i in range(batch_size)]  # 計算小批次各個樣本開始載入的位置

        for time in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, time] = x[(offset + self.time_idx) % data_size]
                batch_t[i, time] = t[(offset + self.time_idx) % data_size]
            self.time_idx += 1
        return batch_x, batch_t

    def fit(self, xs, ts, max_epoch=10, batch_size=20, time_size=35,
            max_grad=None, eval_interval=20):
        data_size = len(xs)
        max_iters = data_size // (batch_size * time_size)
        self.time_idx = 0
        self.ppl_list = []
        self.eval_interval = eval_interval
        model, optimizer = self.model, self.optimizer
        total_loss = 0
        loss_count = 0

        start_time = time.time()
        for epoch in range(max_epoch):
            for iters in range(max_iters):
                batch_x, batch_t = self.get_batch(xs, ts, batch_size, time_size)

                # 計算梯度，更新參數
                loss = model.forward(batch_x, batch_t)
                model.backward()
                params, grads = remove_duplicate(model.params, model.grads)  # 把共用的權重整合成一個
                if max_grad is not None:
                    clip_grads(grads, max_grad)
                optimizer.update(params, grads)
                total_loss += loss
                loss_count += 1

                # 評估困惑度
                if (eval_interval is not None) and (iters % eval_interval) == 0:
                    ppl = np.exp(total_loss / loss_count)
                    elapsed_time = time.time() - start_time
                    print('| epoch %d |  iter %d / %d | time %d[s] | perplexity %.2f'
                          % (self.current_epoch + 1, iters + 1, max_iters, elapsed_time, ppl))
                    self.ppl_list.append(float(ppl))
                    total_loss, loss_count = 0, 0

            self.current_epoch += 1

    def plot(self, ylim=None):
        x = numpy.arange(len(self.ppl_list))
        if ylim is not None:
            plt.ylim(*ylim)
        plt.plot(x, self.ppl_list, label='train')
        plt.xlabel('iterations (x' + str(self.eval_interval) + ')')
        plt.ylabel('perplexity')
        plt.show()


def remove_duplicate(params, grads):
    '''
    把參數陣列中重複的權重整合成一個，並加上對應該權重的梯度
    '''
    params, grads = params[:], grads[:]  # copy list

    while True:
        find_flg = False
        L = len(params)

        for i in range(0, L - 1):
            for j in range(i + 1, L):
                # 共用權重時
                if params[i] is params[j]:
                    grads[i] += grads[j]  # 加上梯度
                    find_flg = True
                    params.pop(j)
                    grads.pop(j)
                # 當作轉置矩陣，共用權重時（weight tying）
                elif params[i].ndim == 2 and params[j].ndim == 2 and \
                     params[i].T.shape == params[j].shape and np.all(params[i].T == params[j]):
                    grads[i] += grads[j].T
                    find_flg = True
                    params.pop(j)
                    grads.pop(j)

                if find_flg: break
            if find_flg: break

        if not find_flg: break

    return params, grads

# %% [markdown]
# # Train Data

# %%
window_size = 1
hidden_size = 5
batch_size = 3
max_epoch = 1000

text = ''' I'm trying to import a couple .txt files into Colab from my own Google Drive. The colab notebook I'm using is in the same folder as the files I want to upload within that notebook. While there is documentation on file I/O on External data: Local Files, Drive, Sheets, and Cloud Storage within Colab, the descriptions do not seem to fit what I'm looking for (e.g. I could upload these files directly from my local directory each time I use the notebook, but instead, I would like to have a cell written that loads them once and keeps them loaded via a connection to my own Drive). Also, the .txt files I want to upload contain samples of plain text to use for training a deep learning algorithm on sentiment analysis, and thus does not appear to be convertable to a .csv for functionally equivalent application (which might be solved by Google Sheets).'''
corpus, word_to_id, id_to_word = preprocess(text)

vocab_size = len(word_to_id)
contexts, target = create_contexts_target(corpus, window_size)
target = convert_one_hot(target, vocab_size)
contexts = convert_one_hot(contexts, vocab_size)

model = SimpleSkipGram(vocab_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

word_vecs = model.word_vecs
for word_id, word in id_to_word.items():
    print(word, word_vecs[word_id])
# Out:
# | epoch 1 |  iter 1 / 53 | time 0[s] | loss 9.31
# | epoch 1 |  iter 31 / 53 | time 0[s] | loss 9.31
# | epoch 2 |  iter 1 / 53 | time 0[s] | loss 9.31
# | epoch 2 |  iter 31 / 53 | time 0[s] | loss 9.31
# | epoch 3 |  iter 1 / 53 | time 0[s] | loss 9.31
# | epoch 3 |  iter 31 / 53 | time 0[s] | loss 9.31
# | epoch 4 |  iter 1 / 53 | time 0[s] | loss 9.30
# | epoch 4 |  iter 31 / 53 | time 0[s] | loss 9.30
# | epoch 5 |  iter 1 / 53 | time 0[s] | loss 9.30
# | epoch 5 |  iter 31 / 53 | time 0[s] | loss 9.29
# | epoch 6 |  iter 1 / 53 | time 0[s] | loss 9.29
# | epoch 6 |  iter 31 / 53 | time 0[s] | loss 9.28
# | epoch 7 |  iter 1 / 53 | time 0[s] | loss 9.27
# | epoch 7 |  iter 31 / 53 | time 0[s] | loss 9.26
# | epoch 8 |  iter 1 / 53 | time 0[s] | loss 9.25
# | epoch 8 |  iter 31 / 53 | time 0[s] | loss 9.24
# | epoch 9 |  iter 1 / 53 | time 0[s] | loss 9.23
# | epoch 9 |  iter 31 / 53 | time 0[s] | loss 9.21
# | epoch 10 |  iter 1 / 53 | time 0[s] | loss 9.21
# | epoch 10 |  iter 31 / 53 | time 0[s] | loss 9.18
# | epoch 11 |  iter 1 / 53 | time 0[s] | loss 9.17
# | epoch 11 |  iter 31 / 53 | time 0[s] | loss 9.15
# | epoch 12 |  iter 1 / 53 | time 0[s] | loss 9.13
# | epoch 12 |  iter 31 / 53 | time 0[s] | loss 9.12
# | epoch 13 |  iter 1 / 53 | time 0[s] | loss 9.07
# | epoch 13 |  iter 31 / 53 | time 0[s] | loss 9.07
# | epoch 14 |  iter 1 / 53 | time 0[s] | loss 9.04
# | epoch 14 |  iter 31 / 53 | time 0[s] | loss 9.03
# | epoch 15 |  iter 1 / 53 | time 0[s] | loss 8.99
# | epoch 15 |  iter 31 / 53 | time 0[s] | loss 8.96
# | epoch 16 |  iter 1 / 53 | time 0[s] | loss 8.97
# | epoch 16 |  iter 31 / 53 | time 0[s] | loss 8.91
# | epoch 17 |  iter 1 / 53 | time 0[s] | loss 8.92
# | epoch 17 |  iter 31 / 53 | time 0[s] | loss 8.86
# | epoch 18 |  iter 1 / 53 | time 0[s] | loss 8.87
# | epoch 18 |  iter 31 / 53 | time 0[s] | loss 8.81
# | epoch 19 |  iter 1 / 53 | time 0[s] | loss 8.78
# | epoch 19 |  iter 31 / 53 | time 0[s] | loss 8.78
# | epoch 20 |  iter 1 / 53 | time 0[s] | loss 8.71
# | epoch 20 |  iter 31 / 53 | time 0[s] | loss 8.70
# | epoch 21 |  iter 1 / 53 | time 0[s] | loss 8.65
# | epoch 21 |  iter 31 / 53 | time 0[s] | loss 8.63
# | epoch 22 |  iter 1 / 53 | time 0[s] | loss 8.63
# | epoch 22 |  iter 31 / 53 | time 0[s] | loss 8.55
# | epoch 23 |  iter 1 / 53 | time 0[s] | loss 8.57
# | epoch 23 |  iter 31 / 53 | time 0[s] | loss 8.52
# | epoch 24 |  iter 1 / 53 | time 0[s] | loss 8.45
# | epoch 24 |  iter 31 / 53 | time 0[s] | loss 8.42
# | epoch 25 |  iter 1 / 53 | time 0[s] | loss 8.47
# | epoch 25 |  iter 31 / 53 | time 0[s] | loss 8.39
# | epoch 26 |  iter 1 / 53 | time 0[s] | loss 8.36
# | epoch 26 |  iter 31 / 53 | time 0[s] | loss 8.27
# | epoch 27 |  iter 1 / 53 | time 0[s] | loss 8.33
# | epoch 27 |  iter 31 / 53 | time 0[s] | loss 8.29
# | epoch 28 |  iter 1 / 53 | time 0[s] | loss 8.16
# | epoch 28 |  iter 31 / 53 | time 0[s] | loss 8.19
# | epoch 29 |  iter 1 / 53 | time 0[s] | loss 8.12
# | epoch 29 |  iter 31 / 53 | time 0[s] | loss 8.10
# | epoch 30 |  iter 1 / 53 | time 0[s] | loss 8.15
# | epoch 30 |  iter 31 / 53 | time 0[s] | loss 8.09
# | epoch 31 |  iter 1 / 53 | time 0[s] | loss 7.97
# | epoch 31 |  iter 31 / 53 | time 0[s] | loss 7.92
# | epoch 32 |  iter 1 / 53 | time 0[s] | loss 8.08
# | epoch 32 |  iter 31 / 53 | time 0[s] | loss 7.90
# | epoch 33 |  iter 1 / 53 | time 0[s] | loss 7.93
# | epoch 33 |  iter 31 / 53 | time 0[s] | loss 7.81
# | epoch 34 |  iter 1 / 53 | time 0[s] | loss 7.85
# | epoch 34 |  iter 31 / 53 | time 0[s] | loss 7.80
# | epoch 35 |  iter 1 / 53 | time 0[s] | loss 7.77
# | epoch 35 |  iter 31 / 53 | time 0[s] | loss 7.79
# | epoch 36 |  iter 1 / 53 | time 0[s] | loss 7.66
# | epoch 36 |  iter 31 / 53 | time 0[s] | loss 7.64
# | epoch 37 |  iter 1 / 53 | time 0[s] | loss 7.63
# | epoch 37 |  iter 31 / 53 | time 0[s] | loss 7.55
# | epoch 38 |  iter 1 / 53 | time 0[s] | loss 7.69
# | epoch 38 |  iter 31 / 53 | time 0[s] | loss 7.52
# | epoch 39 |  iter 1 / 53 | time 0[s] | loss 7.56
# | epoch 39 |  iter 31 / 53 | time 0[s] | loss 7.50
# | epoch 40 |  iter 1 / 53 | time 0[s] | loss 7.45
# | epoch 40 |  iter 31 / 53 | time 0[s] | loss 7.46
# | epoch 41 |  iter 1 / 53 | time 0[s] | loss 7.41
# | epoch 41 |  iter 31 / 53 | time 0[s] | loss 7.36
# | epoch 42 |  iter 1 / 53 | time 0[s] | loss 7.41
# | epoch 42 |  iter 31 / 53 | time 0[s] | loss 7.17
# | epoch 43 |  iter 1 / 53 | time 0[s] | loss 7.53
# | epoch 43 |  iter 31 / 53 | time 0[s] | loss 7.28
# | epoch 44 |  iter 1 / 53 | time 0[s] | loss 7.24
# | epoch 44 |  iter 31 / 53 | time 0[s] | loss 7.21
# | epoch 45 |  iter 1 / 53 | time 0[s] | loss 7.24
# | epoch 45 |  iter 31 / 53 | time 0[s] | loss 7.09
# | epoch 46 |  iter 1 / 53 | time 0[s] | loss 7.28
# | epoch 46 |  iter 31 / 53 | time 0[s] | loss 7.17
# | epoch 47 |  iter 1 / 53 | time 0[s] | loss 7.08
# | epoch 47 |  iter 31 / 53 | time 0[s] | loss 7.02
# | epoch 48 |  iter 1 / 53 | time 0[s] | loss 7.11
# | epoch 48 |  iter 31 / 53 | time 0[s] | loss 6.93
# | epoch 49 |  iter 1 / 53 | time 0[s] | loss 7.12
# | epoch 49 |  iter 31 / 53 | time 0[s] | loss 7.04
# | epoch 50 |  iter 1 / 53 | time 0[s] | loss 6.94
# | epoch 50 |  iter 31 / 53 | time 0[s] | loss 6.96
# | epoch 51 |  iter 1 / 53 | time 0[s] | loss 6.87
# | epoch 51 |  iter 31 / 53 | time 0[s] | loss 6.88
# | epoch 52 |  iter 1 / 53 | time 0[s] | loss 6.86
# | epoch 52 |  iter 31 / 53 | time 0[s] | loss 6.76
# | epoch 53 |  iter 1 / 53 | time 0[s] | loss 6.91
# | epoch 53 |  iter 31 / 53 | time 0[s] | loss 6.69
# | epoch 54 |  iter 1 / 53 | time 0[s] | loss 6.96
# | epoch 54 |  iter 31 / 53 | time 0[s] | loss 6.76
# | epoch 55 |  iter 1 / 53 | time 0[s] | loss 6.77
# | epoch 55 |  iter 31 / 53 | time 0[s] | loss 6.66
# | epoch 56 |  iter 1 / 53 | time 0[s] | loss 6.78
# | epoch 56 |  iter 31 / 53 | time 0[s] | loss 6.74
# | epoch 57 |  iter 1 / 53 | time 0[s] | loss 6.65
# | epoch 57 |  iter 31 / 53 | time 0[s] | loss 6.71
# | epoch 58 |  iter 1 / 53 | time 0[s] | loss 6.56
# | epoch 58 |  iter 31 / 53 | time 0[s] | loss 6.52
# | epoch 59 |  iter 1 / 53 | time 0[s] | loss 6.71
# | epoch 59 |  iter 31 / 53 | time 0[s] | loss 6.51
# | epoch 60 |  iter 1 / 53 | time 0[s] | loss 6.64
# | epoch 60 |  iter 31 / 53 | time 0[s] | loss 6.48
# | epoch 61 |  iter 1 / 53 | time 0[s] | loss 6.64
# | epoch 61 |  iter 31 / 53 | time 0[s] | loss 6.54
# | epoch 62 |  iter 1 / 53 | time 0[s] | loss 6.52
# | epoch 62 |  iter 31 / 53 | time 0[s] | loss 6.52
# | epoch 63 |  iter 1 / 53 | time 0[s] | loss 6.39
# | epoch 63 |  iter 31 / 53 | time 0[s] | loss 6.52
# | epoch 64 |  iter 1 / 53 | time 0[s] | loss 6.34
# | epoch 64 |  iter 31 / 53 | time 0[s] | loss 6.40
# | epoch 65 |  iter 1 / 53 | time 0[s] | loss 6.33
# | epoch 65 |  iter 31 / 53 | time 0[s] | loss 6.22
# | epoch 66 |  iter 1 / 53 | time 0[s] | loss 6.54
# | epoch 66 |  iter 31 / 53 | time 0[s] | loss 6.40
# | epoch 67 |  iter 1 / 53 | time 0[s] | loss 6.27
# | epoch 67 |  iter 31 / 53 | time 0[s] | loss 6.38
# | epoch 68 |  iter 1 / 53 | time 0[s] | loss 6.23
# | epoch 68 |  iter 31 / 53 | time 0[s] | loss 6.34
# | epoch 69 |  iter 1 / 53 | time 0[s] | loss 6.11
# | epoch 69 |  iter 31 / 53 | time 0[s] | loss 6.34
# | epoch 70 |  iter 1 / 53 | time 0[s] | loss 6.26
# | epoch 70 |  iter 31 / 53 | time 0[s] | loss 6.21
# | epoch 71 |  iter 1 / 53 | time 1[s] | loss 6.21
# | epoch 71 |  iter 31 / 53 | time 1[s] | loss 6.12
# | epoch 72 |  iter 1 / 53 | time 1[s] | loss 6.34
# | epoch 72 |  iter 31 / 53 | time 1[s] | loss 6.10
# | epoch 73 |  iter 1 / 53 | time 1[s] | loss 6.26
# | epoch 73 |  iter 31 / 53 | time 1[s] | loss 5.95
# | epoch 74 |  iter 1 / 53 | time 1[s] | loss 6.35
# | epoch 74 |  iter 31 / 53 | time 1[s] | loss 6.20
# | epoch 75 |  iter 1 / 53 | time 1[s] | loss 6.08
# | epoch 75 |  iter 31 / 53 | time 1[s] | loss 6.03
# | epoch 76 |  iter 1 / 53 | time 1[s] | loss 6.13
# | epoch 76 |  iter 31 / 53 | time 1[s] | loss 5.89
# | epoch 77 |  iter 1 / 53 | time 1[s] | loss 6.18
# | epoch 77 |  iter 31 / 53 | time 1[s] | loss 6.01
# | epoch 78 |  iter 1 / 53 | time 1[s] | loss 6.16
# | epoch 78 |  iter 31 / 53 | time 1[s] | loss 6.00
# | epoch 79 |  iter 1 / 53 | time 1[s] | loss 6.02
# | epoch 79 |  iter 31 / 53 | time 1[s] | loss 5.95
# | epoch 80 |  iter 1 / 53 | time 1[s] | loss 5.99
# | epoch 80 |  iter 31 / 53 | time 1[s] | loss 6.09
# | epoch 81 |  iter 1 / 53 | time 1[s] | loss 5.86
# | epoch 81 |  iter 31 / 53 | time 1[s] | loss 5.88
# | epoch 82 |  iter 1 / 53 | time 1[s] | loss 5.89
# | epoch 82 |  iter 31 / 53 | time 1[s] | loss 5.87
# | epoch 83 |  iter 1 / 53 | time 1[s] | loss 6.05
# | epoch 83 |  iter 31 / 53 | time 1[s] | loss 5.82
# | epoch 84 |  iter 1 / 53 | time 1[s] | loss 5.91
# | epoch 84 |  iter 31 / 53 | time 1[s] | loss 5.70
# | epoch 85 |  iter 1 / 53 | time 1[s] | loss 6.06
# | epoch 85 |  iter 31 / 53 | time 1[s] | loss 5.83
# | epoch 86 |  iter 1 / 53 | time 1[s] | loss 5.83
# | epoch 86 |  iter 31 / 53 | time 1[s] | loss 5.88
# | epoch 87 |  iter 1 / 53 | time 1[s] | loss 5.70
# | epoch 87 |  iter 31 / 53 | time 1[s] | loss 5.99
# | epoch 88 |  iter 1 / 53 | time 1[s] | loss 5.52
# | epoch 88 |  iter 31 / 53 | time 1[s] | loss 5.87
# | epoch 89 |  iter 1 / 53 | time 1[s] | loss 5.64
# | epoch 89 |  iter 31 / 53 | time 1[s] | loss 6.08
# | epoch 90 |  iter 1 / 53 | time 1[s] | loss 5.38
# | epoch 90 |  iter 31 / 53 | time 1[s] | loss 5.58
# | epoch 91 |  iter 1 / 53 | time 1[s] | loss 5.93
# | epoch 91 |  iter 31 / 53 | time 1[s] | loss 5.85
# | epoch 92 |  iter 1 / 53 | time 1[s] | loss 5.41
# | epoch 92 |  iter 31 / 53 | time 1[s] | loss 5.76
# | epoch 93 |  iter 1 / 53 | time 1[s] | loss 5.63
# | epoch 93 |  iter 31 / 53 | time 1[s] | loss 5.65
# | epoch 94 |  iter 1 / 53 | time 1[s] | loss 5.76
# | epoch 94 |  iter 31 / 53 | time 1[s] | loss 5.57
# | epoch 95 |  iter 1 / 53 | time 1[s] | loss 5.82
# | epoch 95 |  iter 31 / 53 | time 1[s] | loss 5.59
# | epoch 96 |  iter 1 / 53 | time 1[s] | loss 5.64
# | epoch 96 |  iter 31 / 53 | time 1[s] | loss 5.58
# | epoch 97 |  iter 1 / 53 | time 1[s] | loss 5.69
# | epoch 97 |  iter 31 / 53 | time 1[s] | loss 5.65
# | epoch 98 |  iter 1 / 53 | time 1[s] | loss 5.47
# | epoch 98 |  iter 31 / 53 | time 1[s] | loss 5.32
# | epoch 99 |  iter 1 / 53 | time 1[s] | loss 5.97
# | epoch 99 |  iter 31 / 53 | time 1[s] | loss 5.51
# | epoch 100 |  iter 1 / 53 | time 1[s] | loss 5.64
# | epoch 100 |  iter 31 / 53 | time 1[s] | loss 5.58
# | epoch 101 |  iter 1 / 53 | time 1[s] | loss 5.47
# | epoch 101 |  iter 31 / 53 | time 1[s] | loss 5.42
# | epoch 102 |  iter 1 / 53 | time 1[s] | loss 5.65
# | epoch 102 |  iter 31 / 53 | time 1[s] | loss 5.52
# | epoch 103 |  iter 1 / 53 | time 1[s] | loss 5.48
# | epoch 103 |  iter 31 / 53 | time 1[s] | loss 5.52
# | epoch 104 |  iter 1 / 53 | time 1[s] | loss 5.52
# | epoch 104 |  iter 31 / 53 | time 1[s] | loss 5.48
# | epoch 105 |  iter 1 / 53 | time 1[s] | loss 5.38
# | epoch 105 |  iter 31 / 53 | time 1[s] | loss 5.33
# | epoch 106 |  iter 1 / 53 | time 1[s] | loss 5.50
# | epoch 106 |  iter 31 / 53 | time 1[s] | loss 5.46
# | epoch 107 |  iter 1 / 53 | time 1[s] | loss 5.58
# | epoch 107 |  iter 31 / 53 | time 1[s] | loss 5.51
# | epoch 108 |  iter 1 / 53 | time 1[s] | loss 5.17
# | epoch 108 |  iter 31 / 53 | time 1[s] | loss 5.63
# | epoch 109 |  iter 1 / 53 | time 1[s] | loss 5.14
# | epoch 109 |  iter 31 / 53 | time 1[s] | loss 5.35
# | epoch 110 |  iter 1 / 53 | time 1[s] | loss 5.37
# | epoch 110 |  iter 31 / 53 | time 1[s] | loss 5.42
# | epoch 111 |  iter 1 / 53 | time 1[s] | loss 5.25
# | epoch 111 |  iter 31 / 53 | time 1[s] | loss 5.23
# | epoch 112 |  iter 1 / 53 | time 1[s] | loss 5.62
# | epoch 112 |  iter 31 / 53 | time 1[s] | loss 5.40
# | epoch 113 |  iter 1 / 53 | time 1[s] | loss 5.29
# | epoch 113 |  iter 31 / 53 | time 1[s] | loss 5.49
# | epoch 114 |  iter 1 / 53 | time 1[s] | loss 5.09
# | epoch 114 |  iter 31 / 53 | time 1[s] | loss 5.23
# | epoch 115 |  iter 1 / 53 | time 1[s] | loss 5.47
# | epoch 115 |  iter 31 / 53 | time 1[s] | loss 5.35
# | epoch 116 |  iter 1 / 53 | time 1[s] | loss 5.21
# | epoch 116 |  iter 31 / 53 | time 1[s] | loss 5.39
# | epoch 117 |  iter 1 / 53 | time 1[s] | loss 5.19
# | epoch 117 |  iter 31 / 53 | time 1[s] | loss 5.20
# | epoch 118 |  iter 1 / 53 | time 1[s] | loss 5.35
# | epoch 118 |  iter 31 / 53 | time 1[s] | loss 5.50
# | epoch 119 |  iter 1 / 53 | time 1[s] | loss 4.95
# | epoch 119 |  iter 31 / 53 | time 1[s] | loss 5.22
# | epoch 120 |  iter 1 / 53 | time 1[s] | loss 5.15
# | epoch 120 |  iter 31 / 53 | time 1[s] | loss 5.33
# | epoch 121 |  iter 1 / 53 | time 1[s] | loss 5.14
# | epoch 121 |  iter 31 / 53 | time 1[s] | loss 5.21
# | epoch 122 |  iter 1 / 53 | time 1[s] | loss 5.19
# | epoch 122 |  iter 31 / 53 | time 1[s] | loss 5.45
# | epoch 123 |  iter 1 / 53 | time 1[s] | loss 4.94
# | epoch 123 |  iter 31 / 53 | time 1[s] | loss 5.14
# | epoch 124 |  iter 1 / 53 | time 1[s] | loss 5.34
# | epoch 124 |  iter 31 / 53 | time 1[s] | loss 5.14
# | epoch 125 |  iter 1 / 53 | time 1[s] | loss 5.14
# | epoch 125 |  iter 31 / 53 | time 1[s] | loss 5.19
# | epoch 126 |  iter 1 / 53 | time 1[s] | loss 5.01
# | epoch 126 |  iter 31 / 53 | time 1[s] | loss 5.24
# | epoch 127 |  iter 1 / 53 | time 1[s] | loss 5.05
# | epoch 127 |  iter 31 / 53 | time 1[s] | loss 5.06
# | epoch 128 |  iter 1 / 53 | time 1[s] | loss 5.15
# | epoch 128 |  iter 31 / 53 | time 1[s] | loss 5.22
# | epoch 129 |  iter 1 / 53 | time 1[s] | loss 4.96
# | epoch 129 |  iter 31 / 53 | time 1[s] | loss 4.92
# | epoch 130 |  iter 1 / 53 | time 1[s] | loss 5.34
# | epoch 130 |  iter 31 / 53 | time 1[s] | loss 5.16
# | epoch 131 |  iter 1 / 53 | time 1[s] | loss 4.93
# | epoch 131 |  iter 31 / 53 | time 1[s] | loss 5.15
# | epoch 132 |  iter 1 / 53 | time 1[s] | loss 5.02
# | epoch 132 |  iter 31 / 53 | time 1[s] | loss 5.05
# | epoch 133 |  iter 1 / 53 | time 1[s] | loss 5.08
# | epoch 133 |  iter 31 / 53 | time 1[s] | loss 4.75
# | epoch 134 |  iter 1 / 53 | time 1[s] | loss 5.36
# | epoch 134 |  iter 31 / 53 | time 1[s] | loss 5.22
# | epoch 135 |  iter 1 / 53 | time 1[s] | loss 4.79
# | epoch 135 |  iter 31 / 53 | time 1[s] | loss 4.96
# | epoch 136 |  iter 1 / 53 | time 1[s] | loss 5.10
# | epoch 136 |  iter 31 / 53 | time 1[s] | loss 5.01
# | epoch 137 |  iter 1 / 53 | time 1[s] | loss 5.02
# | epoch 137 |  iter 31 / 53 | time 1[s] | loss 4.96
# | epoch 138 |  iter 1 / 53 | time 1[s] | loss 5.10
# | epoch 138 |  iter 31 / 53 | time 1[s] | loss 5.08
# | epoch 139 |  iter 1 / 53 | time 1[s] | loss 4.87
# | epoch 139 |  iter 31 / 53 | time 1[s] | loss 5.08
# | epoch 140 |  iter 1 / 53 | time 1[s] | loss 4.72
# | epoch 140 |  iter 31 / 53 | time 1[s] | loss 5.03
# | epoch 141 |  iter 1 / 53 | time 1[s] | loss 4.92
# | epoch 141 |  iter 31 / 53 | time 1[s] | loss 4.74
# | epoch 142 |  iter 1 / 53 | time 1[s] | loss 5.28
# | epoch 142 |  iter 31 / 53 | time 2[s] | loss 4.85
# | epoch 143 |  iter 1 / 53 | time 2[s] | loss 4.98
# | epoch 143 |  iter 31 / 53 | time 2[s] | loss 4.91
# | epoch 144 |  iter 1 / 53 | time 2[s] | loss 4.95
# | epoch 144 |  iter 31 / 53 | time 2[s] | loss 4.99
# | epoch 145 |  iter 1 / 53 | time 2[s] | loss 4.81
# | epoch 145 |  iter 31 / 53 | time 2[s] | loss 4.93
# | epoch 146 |  iter 1 / 53 | time 2[s] | loss 4.88
# | epoch 146 |  iter 31 / 53 | time 2[s] | loss 4.69
# | epoch 147 |  iter 1 / 53 | time 2[s] | loss 4.97
# | epoch 147 |  iter 31 / 53 | time 2[s] | loss 5.05
# | epoch 148 |  iter 1 / 53 | time 2[s] | loss 4.66
# | epoch 148 |  iter 31 / 53 | time 2[s] | loss 4.70
# | epoch 149 |  iter 1 / 53 | time 2[s] | loss 5.20
# | epoch 149 |  iter 31 / 53 | time 2[s] | loss 4.81
# | epoch 150 |  iter 1 / 53 | time 2[s] | loss 4.90
# | epoch 150 |  iter 31 / 53 | time 2[s] | loss 4.75
# | epoch 151 |  iter 1 / 53 | time 2[s] | loss 4.86
# | epoch 151 |  iter 31 / 53 | time 2[s] | loss 4.85
# | epoch 152 |  iter 1 / 53 | time 2[s] | loss 4.76
# | epoch 152 |  iter 31 / 53 | time 2[s] | loss 4.69
# | epoch 153 |  iter 1 / 53 | time 2[s] | loss 4.98
# | epoch 153 |  iter 31 / 53 | time 2[s] | loss 4.89
# | epoch 154 |  iter 1 / 53 | time 2[s] | loss 4.83
# | epoch 154 |  iter 31 / 53 | time 2[s] | loss 4.85
# | epoch 155 |  iter 1 / 53 | time 2[s] | loss 4.70
# | epoch 155 |  iter 31 / 53 | time 2[s] | loss 4.74
# | epoch 156 |  iter 1 / 53 | time 2[s] | loss 4.96
# | epoch 156 |  iter 31 / 53 | time 2[s] | loss 4.63
# | epoch 157 |  iter 1 / 53 | time 2[s] | loss 4.98
# | epoch 157 |  iter 31 / 53 | time 2[s] | loss 4.72
# | epoch 158 |  iter 1 / 53 | time 2[s] | loss 4.80
# | epoch 158 |  iter 31 / 53 | time 2[s] | loss 4.69
# | epoch 159 |  iter 1 / 53 | time 2[s] | loss 4.88
# | epoch 159 |  iter 31 / 53 | time 2[s] | loss 4.59
# | epoch 160 |  iter 1 / 53 | time 2[s] | loss 4.77
# | epoch 160 |  iter 31 / 53 | time 2[s] | loss 4.72
# | epoch 161 |  iter 1 / 53 | time 2[s] | loss 4.83
# | epoch 161 |  iter 31 / 53 | time 2[s] | loss 4.72
# | epoch 162 |  iter 1 / 53 | time 2[s] | loss 4.79
# | epoch 162 |  iter 31 / 53 | time 2[s] | loss 4.59
# | epoch 163 |  iter 1 / 53 | time 2[s] | loss 4.88
# | epoch 163 |  iter 31 / 53 | time 2[s] | loss 4.51
# | epoch 164 |  iter 1 / 53 | time 2[s] | loss 4.98
# | epoch 164 |  iter 31 / 53 | time 2[s] | loss 4.67
# | epoch 165 |  iter 1 / 53 | time 2[s] | loss 4.71
# | epoch 165 |  iter 31 / 53 | time 2[s] | loss 4.79
# | epoch 166 |  iter 1 / 53 | time 2[s] | loss 4.58
# | epoch 166 |  iter 31 / 53 | time 2[s] | loss 4.77
# | epoch 167 |  iter 1 / 53 | time 2[s] | loss 4.39
# | epoch 167 |  iter 31 / 53 | time 2[s] | loss 4.73
# | epoch 168 |  iter 1 / 53 | time 2[s] | loss 4.72
# | epoch 168 |  iter 31 / 53 | time 2[s] | loss 4.47
# | epoch 169 |  iter 1 / 53 | time 2[s] | loss 4.85
# | epoch 169 |  iter 31 / 53 | time 2[s] | loss 4.73
# | epoch 170 |  iter 1 / 53 | time 2[s] | loss 4.54
# | epoch 170 |  iter 31 / 53 | time 2[s] | loss 4.49
# | epoch 171 |  iter 1 / 53 | time 2[s] | loss 4.80
# | epoch 171 |  iter 31 / 53 | time 2[s] | loss 4.73
# | epoch 172 |  iter 1 / 53 | time 2[s] | loss 4.49
# | epoch 172 |  iter 31 / 53 | time 2[s] | loss 4.61
# | epoch 173 |  iter 1 / 53 | time 2[s] | loss 4.62
# | epoch 173 |  iter 31 / 53 | time 2[s] | loss 4.73
# | epoch 174 |  iter 1 / 53 | time 2[s] | loss 4.45
# | epoch 174 |  iter 31 / 53 | time 2[s] | loss 4.58
# | epoch 175 |  iter 1 / 53 | time 2[s] | loss 4.59
# | epoch 175 |  iter 31 / 53 | time 2[s] | loss 4.57
# | epoch 176 |  iter 1 / 53 | time 2[s] | loss 4.63
# | epoch 176 |  iter 31 / 53 | time 2[s] | loss 4.57
# | epoch 177 |  iter 1 / 53 | time 2[s] | loss 4.68
# | epoch 177 |  iter 31 / 53 | time 2[s] | loss 4.49
# | epoch 178 |  iter 1 / 53 | time 2[s] | loss 4.59
# | epoch 178 |  iter 31 / 53 | time 2[s] | loss 4.50
# | epoch 179 |  iter 1 / 53 | time 2[s] | loss 4.83
# | epoch 179 |  iter 31 / 53 | time 2[s] | loss 4.51
# | epoch 180 |  iter 1 / 53 | time 2[s] | loss 4.49
# | epoch 180 |  iter 31 / 53 | time 2[s] | loss 4.69
# | epoch 181 |  iter 1 / 53 | time 2[s] | loss 4.35
# | epoch 181 |  iter 31 / 53 | time 2[s] | loss 4.64
# | epoch 182 |  iter 1 / 53 | time 2[s] | loss 4.43
# | epoch 182 |  iter 31 / 53 | time 2[s] | loss 4.53
# | epoch 183 |  iter 1 / 53 | time 2[s] | loss 4.51
# | epoch 183 |  iter 31 / 53 | time 2[s] | loss 4.64
# | epoch 184 |  iter 1 / 53 | time 2[s] | loss 4.30
# | epoch 184 |  iter 31 / 53 | time 2[s] | loss 4.31
# | epoch 185 |  iter 1 / 53 | time 2[s] | loss 4.80
# | epoch 185 |  iter 31 / 53 | time 2[s] | loss 4.65
# | epoch 186 |  iter 1 / 53 | time 2[s] | loss 4.25
# | epoch 186 |  iter 31 / 53 | time 2[s] | loss 4.38
# | epoch 187 |  iter 1 / 53 | time 2[s] | loss 4.70
# | epoch 187 |  iter 31 / 53 | time 2[s] | loss 4.51
# | epoch 188 |  iter 1 / 53 | time 2[s] | loss 4.48
# | epoch 188 |  iter 31 / 53 | time 2[s] | loss 4.66
# | epoch 189 |  iter 1 / 53 | time 2[s] | loss 4.26
# | epoch 189 |  iter 31 / 53 | time 2[s] | loss 4.42
# | epoch 190 |  iter 1 / 53 | time 2[s] | loss 4.51
# | epoch 190 |  iter 31 / 53 | time 2[s] | loss 4.65
# | epoch 191 |  iter 1 / 53 | time 2[s] | loss 4.14
# | epoch 191 |  iter 31 / 53 | time 2[s] | loss 4.49
# | epoch 192 |  iter 1 / 53 | time 2[s] | loss 4.35
# | epoch 192 |  iter 31 / 53 | time 2[s] | loss 4.34
# | epoch 193 |  iter 1 / 53 | time 2[s] | loss 4.67
# | epoch 193 |  iter 31 / 53 | time 2[s] | loss 4.48
# | epoch 194 |  iter 1 / 53 | time 2[s] | loss 4.33
# | epoch 194 |  iter 31 / 53 | time 2[s] | loss 4.28
# | epoch 195 |  iter 1 / 53 | time 2[s] | loss 4.64
# | epoch 195 |  iter 31 / 53 | time 2[s] | loss 4.47
# | epoch 196 |  iter 1 / 53 | time 2[s] | loss 4.33
# | epoch 196 |  iter 31 / 53 | time 2[s] | loss 4.34
# | epoch 197 |  iter 1 / 53 | time 2[s] | loss 4.47
# | epoch 197 |  iter 31 / 53 | time 2[s] | loss 4.47
# | epoch 198 |  iter 1 / 53 | time 2[s] | loss 4.26
# | epoch 198 |  iter 31 / 53 | time 2[s] | loss 4.24
# | epoch 199 |  iter 1 / 53 | time 2[s] | loss 4.48
# | epoch 199 |  iter 31 / 53 | time 2[s] | loss 4.55
# | epoch 200 |  iter 1 / 53 | time 2[s] | loss 4.16
# | epoch 200 |  iter 31 / 53 | time 2[s] | loss 4.45
# | epoch 201 |  iter 1 / 53 | time 2[s] | loss 4.31
# | epoch 201 |  iter 31 / 53 | time 2[s] | loss 4.44
# | epoch 202 |  iter 1 / 53 | time 2[s] | loss 4.37
# | epoch 202 |  iter 31 / 53 | time 2[s] | loss 4.52
# | epoch 203 |  iter 1 / 53 | time 2[s] | loss 4.16
# | epoch 203 |  iter 31 / 53 | time 2[s] | loss 4.39
# | epoch 204 |  iter 1 / 53 | time 2[s] | loss 4.28
# | epoch 204 |  iter 31 / 53 | time 2[s] | loss 4.43
# | epoch 205 |  iter 1 / 53 | time 2[s] | loss 4.38
# | epoch 205 |  iter 31 / 53 | time 2[s] | loss 4.42
# | epoch 206 |  iter 1 / 53 | time 2[s] | loss 4.22
# | epoch 206 |  iter 31 / 53 | time 2[s] | loss 4.18
# | epoch 207 |  iter 1 / 53 | time 2[s] | loss 4.43
# | epoch 207 |  iter 31 / 53 | time 2[s] | loss 4.26
# | epoch 208 |  iter 1 / 53 | time 2[s] | loss 4.44
# | epoch 208 |  iter 31 / 53 | time 2[s] | loss 4.23
# | epoch 209 |  iter 1 / 53 | time 2[s] | loss 4.50
# | epoch 209 |  iter 31 / 53 | time 2[s] | loss 4.38
# | epoch 210 |  iter 1 / 53 | time 2[s] | loss 4.14
# | epoch 210 |  iter 31 / 53 | time 2[s] | loss 4.40
# | epoch 211 |  iter 1 / 53 | time 2[s] | loss 4.05
# | epoch 211 |  iter 31 / 53 | time 2[s] | loss 4.33
# | epoch 212 |  iter 1 / 53 | time 2[s] | loss 4.42
# | epoch 212 |  iter 31 / 53 | time 3[s] | loss 4.49
# | epoch 213 |  iter 1 / 53 | time 3[s] | loss 3.92
# | epoch 213 |  iter 31 / 53 | time 3[s] | loss 4.23
# | epoch 214 |  iter 1 / 53 | time 3[s] | loss 4.36
# | epoch 214 |  iter 31 / 53 | time 3[s] | loss 4.25
# | epoch 215 |  iter 1 / 53 | time 3[s] | loss 4.36
# | epoch 215 |  iter 31 / 53 | time 3[s] | loss 4.16
# | epoch 216 |  iter 1 / 53 | time 3[s] | loss 4.39
# | epoch 216 |  iter 31 / 53 | time 3[s] | loss 4.20
# | epoch 217 |  iter 1 / 53 | time 3[s] | loss 4.39
# | epoch 217 |  iter 31 / 53 | time 3[s] | loss 4.20
# | epoch 218 |  iter 1 / 53 | time 3[s] | loss 4.24
# | epoch 218 |  iter 31 / 53 | time 3[s] | loss 4.15
# | epoch 219 |  iter 1 / 53 | time 3[s] | loss 4.44
# | epoch 219 |  iter 31 / 53 | time 3[s] | loss 4.32
# | epoch 220 |  iter 1 / 53 | time 3[s] | loss 4.09
# | epoch 220 |  iter 31 / 53 | time 3[s] | loss 4.24
# | epoch 221 |  iter 1 / 53 | time 3[s] | loss 4.29
# | epoch 221 |  iter 31 / 53 | time 3[s] | loss 4.24
# | epoch 222 |  iter 1 / 53 | time 3[s] | loss 4.07
# | epoch 222 |  iter 31 / 53 | time 3[s] | loss 4.42
# | epoch 223 |  iter 1 / 53 | time 3[s] | loss 3.94
# | epoch 223 |  iter 31 / 53 | time 3[s] | loss 4.21
# | epoch 224 |  iter 1 / 53 | time 3[s] | loss 4.43
# | epoch 224 |  iter 31 / 53 | time 3[s] | loss 4.12
# | epoch 225 |  iter 1 / 53 | time 3[s] | loss 4.20
# | epoch 225 |  iter 31 / 53 | time 3[s] | loss 4.09
# | epoch 226 |  iter 1 / 53 | time 3[s] | loss 4.29
# | epoch 226 |  iter 31 / 53 | time 3[s] | loss 4.28
# | epoch 227 |  iter 1 / 53 | time 3[s] | loss 4.05
# | epoch 227 |  iter 31 / 53 | time 3[s] | loss 4.16
# | epoch 228 |  iter 1 / 53 | time 3[s] | loss 4.24
# | epoch 228 |  iter 31 / 53 | time 3[s] | loss 4.01
# | epoch 229 |  iter 1 / 53 | time 3[s] | loss 4.30
# | epoch 229 |  iter 31 / 53 | time 3[s] | loss 4.29
# | epoch 230 |  iter 1 / 53 | time 3[s] | loss 3.99
# | epoch 230 |  iter 31 / 53 | time 3[s] | loss 4.03
# | epoch 231 |  iter 1 / 53 | time 3[s] | loss 4.40
# | epoch 231 |  iter 31 / 53 | time 3[s] | loss 4.35
# | epoch 232 |  iter 1 / 53 | time 3[s] | loss 3.89
# | epoch 232 |  iter 31 / 53 | time 3[s] | loss 4.45
# | epoch 233 |  iter 1 / 53 | time 3[s] | loss 3.85
# | epoch 233 |  iter 31 / 53 | time 3[s] | loss 4.08
# | epoch 234 |  iter 1 / 53 | time 3[s] | loss 4.19
# | epoch 234 |  iter 31 / 53 | time 3[s] | loss 4.24
# | epoch 235 |  iter 1 / 53 | time 3[s] | loss 3.99
# | epoch 235 |  iter 31 / 53 | time 3[s] | loss 4.12
# | epoch 236 |  iter 1 / 53 | time 3[s] | loss 4.23
# | epoch 236 |  iter 31 / 53 | time 3[s] | loss 3.85
# | epoch 237 |  iter 1 / 53 | time 3[s] | loss 4.46
# | epoch 237 |  iter 31 / 53 | time 3[s] | loss 4.25
# | epoch 238 |  iter 1 / 53 | time 3[s] | loss 4.04
# | epoch 238 |  iter 31 / 53 | time 3[s] | loss 3.93
# | epoch 239 |  iter 1 / 53 | time 3[s] | loss 4.23
# | epoch 239 |  iter 31 / 53 | time 3[s] | loss 4.05
# | epoch 240 |  iter 1 / 53 | time 3[s] | loss 4.26
# | epoch 240 |  iter 31 / 53 | time 3[s] | loss 4.28
# | epoch 241 |  iter 1 / 53 | time 3[s] | loss 3.83
# | epoch 241 |  iter 31 / 53 | time 3[s] | loss 4.04
# | epoch 242 |  iter 1 / 53 | time 3[s] | loss 4.25
# | epoch 242 |  iter 31 / 53 | time 3[s] | loss 4.04
# | epoch 243 |  iter 1 / 53 | time 3[s] | loss 4.14
# | epoch 243 |  iter 31 / 53 | time 3[s] | loss 4.35
# | epoch 244 |  iter 1 / 53 | time 3[s] | loss 3.88
# | epoch 244 |  iter 31 / 53 | time 3[s] | loss 4.20
# | epoch 245 |  iter 1 / 53 | time 3[s] | loss 3.80
# | epoch 245 |  iter 31 / 53 | time 3[s] | loss 4.13
# | epoch 246 |  iter 1 / 53 | time 3[s] | loss 3.90
# | epoch 246 |  iter 31 / 53 | time 3[s] | loss 4.15
# | epoch 247 |  iter 1 / 53 | time 3[s] | loss 3.93
# | epoch 247 |  iter 31 / 53 | time 3[s] | loss 3.78
# | epoch 248 |  iter 1 / 53 | time 3[s] | loss 4.50
# | epoch 248 |  iter 31 / 53 | time 3[s] | loss 3.89
# | epoch 249 |  iter 1 / 53 | time 3[s] | loss 4.25
# | epoch 249 |  iter 31 / 53 | time 3[s] | loss 3.85
# | epoch 250 |  iter 1 / 53 | time 3[s] | loss 4.27
# | epoch 250 |  iter 31 / 53 | time 3[s] | loss 4.09
# | epoch 251 |  iter 1 / 53 | time 3[s] | loss 3.93
# | epoch 251 |  iter 31 / 53 | time 3[s] | loss 3.92
# | epoch 252 |  iter 1 / 53 | time 3[s] | loss 4.40
# | epoch 252 |  iter 31 / 53 | time 3[s] | loss 4.07
# | epoch 253 |  iter 1 / 53 | time 3[s] | loss 3.88
# | epoch 253 |  iter 31 / 53 | time 3[s] | loss 4.04
# | epoch 254 |  iter 1 / 53 | time 3[s] | loss 3.96
# | epoch 254 |  iter 31 / 53 | time 3[s] | loss 3.93
# | epoch 255 |  iter 1 / 53 | time 3[s] | loss 4.27
# | epoch 255 |  iter 31 / 53 | time 3[s] | loss 3.98
# | epoch 256 |  iter 1 / 53 | time 3[s] | loss 3.99
# | epoch 256 |  iter 31 / 53 | time 3[s] | loss 3.80
# | epoch 257 |  iter 1 / 53 | time 3[s] | loss 4.42
# | epoch 257 |  iter 31 / 53 | time 3[s] | loss 4.08
# | epoch 258 |  iter 1 / 53 | time 3[s] | loss 3.84
# | epoch 258 |  iter 31 / 53 | time 3[s] | loss 4.08
# | epoch 259 |  iter 1 / 53 | time 3[s] | loss 3.89
# | epoch 259 |  iter 31 / 53 | time 3[s] | loss 3.79
# | epoch 260 |  iter 1 / 53 | time 3[s] | loss 4.22
# | epoch 260 |  iter 31 / 53 | time 3[s] | loss 4.20
# | epoch 261 |  iter 1 / 53 | time 3[s] | loss 3.71
# | epoch 261 |  iter 31 / 53 | time 3[s] | loss 3.79
# | epoch 262 |  iter 1 / 53 | time 3[s] | loss 4.23
# | epoch 262 |  iter 31 / 53 | time 3[s] | loss 3.87
# | epoch 263 |  iter 1 / 53 | time 3[s] | loss 4.05
# | epoch 263 |  iter 31 / 53 | time 3[s] | loss 4.11
# | epoch 264 |  iter 1 / 53 | time 3[s] | loss 3.86
# | epoch 264 |  iter 31 / 53 | time 3[s] | loss 4.00
# | epoch 265 |  iter 1 / 53 | time 3[s] | loss 3.85
# | epoch 265 |  iter 31 / 53 | time 3[s] | loss 3.92
# | epoch 266 |  iter 1 / 53 | time 3[s] | loss 4.12
# | epoch 266 |  iter 31 / 53 | time 3[s] | loss 3.78
# | epoch 267 |  iter 1 / 53 | time 3[s] | loss 4.04
# | epoch 267 |  iter 31 / 53 | time 3[s] | loss 4.00
# | epoch 268 |  iter 1 / 53 | time 3[s] | loss 3.97
# | epoch 268 |  iter 31 / 53 | time 3[s] | loss 3.77
# | epoch 269 |  iter 1 / 53 | time 3[s] | loss 4.14
# | epoch 269 |  iter 31 / 53 | time 3[s] | loss 3.83
# | epoch 270 |  iter 1 / 53 | time 3[s] | loss 3.97
# | epoch 270 |  iter 31 / 53 | time 3[s] | loss 3.95
# | epoch 271 |  iter 1 / 53 | time 3[s] | loss 3.90
# | epoch 271 |  iter 31 / 53 | time 3[s] | loss 3.99
# | epoch 272 |  iter 1 / 53 | time 3[s] | loss 3.84
# | epoch 272 |  iter 31 / 53 | time 3[s] | loss 3.75
# | epoch 273 |  iter 1 / 53 | time 3[s] | loss 4.26
# | epoch 273 |  iter 31 / 53 | time 3[s] | loss 3.90
# | epoch 274 |  iter 1 / 53 | time 3[s] | loss 3.82
# | epoch 274 |  iter 31 / 53 | time 3[s] | loss 3.63
# | epoch 275 |  iter 1 / 53 | time 3[s] | loss 4.26
# | epoch 275 |  iter 31 / 53 | time 3[s] | loss 3.84
# | epoch 276 |  iter 1 / 53 | time 3[s] | loss 4.08
# | epoch 276 |  iter 31 / 53 | time 3[s] | loss 4.09
# | epoch 277 |  iter 1 / 53 | time 3[s] | loss 3.70
# | epoch 277 |  iter 31 / 53 | time 3[s] | loss 3.79
# | epoch 278 |  iter 1 / 53 | time 3[s] | loss 4.01
# | epoch 278 |  iter 31 / 53 | time 3[s] | loss 3.88
# | epoch 279 |  iter 1 / 53 | time 3[s] | loss 3.94
# | epoch 279 |  iter 31 / 53 | time 3[s] | loss 3.85
# | epoch 280 |  iter 1 / 53 | time 3[s] | loss 3.93
# | epoch 280 |  iter 31 / 53 | time 3[s] | loss 3.79
# | epoch 281 |  iter 1 / 53 | time 3[s] | loss 4.00
# | epoch 281 |  iter 31 / 53 | time 4[s] | loss 3.70
# | epoch 282 |  iter 1 / 53 | time 4[s] | loss 3.99
# | epoch 282 |  iter 31 / 53 | time 4[s] | loss 3.91
# | epoch 283 |  iter 1 / 53 | time 4[s] | loss 3.84
# | epoch 283 |  iter 31 / 53 | time 4[s] | loss 3.85
# | epoch 284 |  iter 1 / 53 | time 4[s] | loss 3.88
# | epoch 284 |  iter 31 / 53 | time 4[s] | loss 4.00
# | epoch 285 |  iter 1 / 53 | time 4[s] | loss 3.74
# | epoch 285 |  iter 31 / 53 | time 4[s] | loss 3.93
# | epoch 286 |  iter 1 / 53 | time 4[s] | loss 3.77
# | epoch 286 |  iter 31 / 53 | time 4[s] | loss 3.94
# | epoch 287 |  iter 1 / 53 | time 4[s] | loss 3.81
# | epoch 287 |  iter 31 / 53 | time 4[s] | loss 3.75
# | epoch 288 |  iter 1 / 53 | time 4[s] | loss 3.94
# | epoch 288 |  iter 31 / 53 | time 4[s] | loss 3.85
# | epoch 289 |  iter 1 / 53 | time 4[s] | loss 3.84
# | epoch 289 |  iter 31 / 53 | time 4[s] | loss 3.94
# | epoch 290 |  iter 1 / 53 | time 4[s] | loss 3.74
# | epoch 290 |  iter 31 / 53 | time 4[s] | loss 3.87
# | epoch 291 |  iter 1 / 53 | time 4[s] | loss 3.79
# | epoch 291 |  iter 31 / 53 | time 4[s] | loss 3.75
# | epoch 292 |  iter 1 / 53 | time 4[s] | loss 3.99
# | epoch 292 |  iter 31 / 53 | time 4[s] | loss 3.88
# | epoch 293 |  iter 1 / 53 | time 4[s] | loss 3.69
# | epoch 293 |  iter 31 / 53 | time 4[s] | loss 3.89
# | epoch 294 |  iter 1 / 53 | time 4[s] | loss 3.62
# | epoch 294 |  iter 31 / 53 | time 4[s] | loss 3.78
# | epoch 295 |  iter 1 / 53 | time 4[s] | loss 3.78
# | epoch 295 |  iter 31 / 53 | time 4[s] | loss 3.69
# | epoch 296 |  iter 1 / 53 | time 4[s] | loss 3.92
# | epoch 296 |  iter 31 / 53 | time 4[s] | loss 4.00
# | epoch 297 |  iter 1 / 53 | time 4[s] | loss 3.67
# | epoch 297 |  iter 31 / 53 | time 4[s] | loss 3.68
# | epoch 298 |  iter 1 / 53 | time 4[s] | loss 4.03
# | epoch 298 |  iter 31 / 53 | time 4[s] | loss 3.79
# | epoch 299 |  iter 1 / 53 | time 4[s] | loss 3.74
# | epoch 299 |  iter 31 / 53 | time 4[s] | loss 3.67
# | epoch 300 |  iter 1 / 53 | time 4[s] | loss 3.90
# | epoch 300 |  iter 31 / 53 | time 4[s] | loss 3.72
# | epoch 301 |  iter 1 / 53 | time 4[s] | loss 3.94
# | epoch 301 |  iter 31 / 53 | time 4[s] | loss 3.73
# | epoch 302 |  iter 1 / 53 | time 4[s] | loss 3.90
# | epoch 302 |  iter 31 / 53 | time 4[s] | loss 3.73
# | epoch 303 |  iter 1 / 53 | time 4[s] | loss 3.85
# | epoch 303 |  iter 31 / 53 | time 4[s] | loss 3.82
# | epoch 304 |  iter 1 / 53 | time 4[s] | loss 3.70
# | epoch 304 |  iter 31 / 53 | time 4[s] | loss 3.66
# | epoch 305 |  iter 1 / 53 | time 4[s] | loss 3.88
# | epoch 305 |  iter 31 / 53 | time 4[s] | loss 3.84
# | epoch 306 |  iter 1 / 53 | time 4[s] | loss 3.72
# | epoch 306 |  iter 31 / 53 | time 4[s] | loss 3.84
# | epoch 307 |  iter 1 / 53 | time 4[s] | loss 3.64
# | epoch 307 |  iter 31 / 53 | time 4[s] | loss 3.65
# | epoch 308 |  iter 1 / 53 | time 4[s] | loss 3.96
# | epoch 308 |  iter 31 / 53 | time 4[s] | loss 3.59
# | epoch 309 |  iter 1 / 53 | time 4[s] | loss 3.89
# | epoch 309 |  iter 31 / 53 | time 4[s] | loss 3.83
# | epoch 310 |  iter 1 / 53 | time 4[s] | loss 3.68
# | epoch 310 |  iter 31 / 53 | time 4[s] | loss 3.80
# | epoch 311 |  iter 1 / 53 | time 4[s] | loss 3.71
# | epoch 311 |  iter 31 / 53 | time 4[s] | loss 3.78
# | epoch 312 |  iter 1 / 53 | time 4[s] | loss 3.62
# | epoch 312 |  iter 31 / 53 | time 4[s] | loss 3.78
# | epoch 313 |  iter 1 / 53 | time 4[s] | loss 3.68
# | epoch 313 |  iter 31 / 53 | time 4[s] | loss 3.67
# | epoch 314 |  iter 1 / 53 | time 4[s] | loss 3.85
# | epoch 314 |  iter 31 / 53 | time 4[s] | loss 4.04
# | epoch 315 |  iter 1 / 53 | time 4[s] | loss 3.26
# | epoch 315 |  iter 31 / 53 | time 4[s] | loss 3.68
# | epoch 316 |  iter 1 / 53 | time 4[s] | loss 3.78
# | epoch 316 |  iter 31 / 53 | time 4[s] | loss 3.59
# | epoch 317 |  iter 1 / 53 | time 4[s] | loss 3.90
# | epoch 317 |  iter 31 / 53 | time 4[s] | loss 3.59
# | epoch 318 |  iter 1 / 53 | time 4[s] | loss 3.87
# | epoch 318 |  iter 31 / 53 | time 4[s] | loss 3.76
# | epoch 319 |  iter 1 / 53 | time 4[s] | loss 3.71
# | epoch 319 |  iter 31 / 53 | time 4[s] | loss 3.60
# | epoch 320 |  iter 1 / 53 | time 4[s] | loss 3.78
# | epoch 320 |  iter 31 / 53 | time 4[s] | loss 3.47
# | epoch 321 |  iter 1 / 53 | time 4[s] | loss 4.04
# | epoch 321 |  iter 31 / 53 | time 4[s] | loss 3.89
# | epoch 322 |  iter 1 / 53 | time 4[s] | loss 3.42
# | epoch 322 |  iter 31 / 53 | time 4[s] | loss 3.88
# | epoch 323 |  iter 1 / 53 | time 4[s] | loss 3.47
# | epoch 323 |  iter 31 / 53 | time 4[s] | loss 3.62
# | epoch 324 |  iter 1 / 53 | time 4[s] | loss 3.91
# | epoch 324 |  iter 31 / 53 | time 4[s] | loss 3.72
# | epoch 325 |  iter 1 / 53 | time 4[s] | loss 3.67
# | epoch 325 |  iter 31 / 53 | time 4[s] | loss 3.53
# | epoch 326 |  iter 1 / 53 | time 4[s] | loss 3.81
# | epoch 326 |  iter 31 / 53 | time 4[s] | loss 3.63
# | epoch 327 |  iter 1 / 53 | time 4[s] | loss 3.77
# | epoch 327 |  iter 31 / 53 | time 4[s] | loss 3.64
# | epoch 328 |  iter 1 / 53 | time 4[s] | loss 3.79
# | epoch 328 |  iter 31 / 53 | time 4[s] | loss 3.70
# | epoch 329 |  iter 1 / 53 | time 4[s] | loss 3.68
# | epoch 329 |  iter 31 / 53 | time 4[s] | loss 3.61
# | epoch 330 |  iter 1 / 53 | time 4[s] | loss 3.69
# | epoch 330 |  iter 31 / 53 | time 4[s] | loss 3.54
# | epoch 331 |  iter 1 / 53 | time 4[s] | loss 3.83
# | epoch 331 |  iter 31 / 53 | time 4[s] | loss 3.72
# | epoch 332 |  iter 1 / 53 | time 4[s] | loss 3.66
# | epoch 332 |  iter 31 / 53 | time 4[s] | loss 3.93
# | epoch 333 |  iter 1 / 53 | time 4[s] | loss 3.43
# | epoch 333 |  iter 31 / 53 | time 4[s] | loss 3.50
# | epoch 334 |  iter 1 / 53 | time 4[s] | loss 3.76
# | epoch 334 |  iter 31 / 53 | time 4[s] | loss 3.82
# | epoch 335 |  iter 1 / 53 | time 4[s] | loss 3.38
# | epoch 335 |  iter 31 / 53 | time 4[s] | loss 3.72
# | epoch 336 |  iter 1 / 53 | time 4[s] | loss 3.51
# | epoch 336 |  iter 31 / 53 | time 4[s] | loss 3.65
# | epoch 337 |  iter 1 / 53 | time 4[s] | loss 3.67
# | epoch 337 |  iter 31 / 53 | time 4[s] | loss 3.61
# | epoch 338 |  iter 1 / 53 | time 4[s] | loss 3.70
# | epoch 338 |  iter 31 / 53 | time 4[s] | loss 3.89
# | epoch 339 |  iter 1 / 53 | time 4[s] | loss 3.28
# | epoch 339 |  iter 31 / 53 | time 4[s] | loss 3.83
# | epoch 340 |  iter 1 / 53 | time 4[s] | loss 3.46
# | epoch 340 |  iter 31 / 53 | time 4[s] | loss 3.68
# | epoch 341 |  iter 1 / 53 | time 4[s] | loss 3.54
# | epoch 341 |  iter 31 / 53 | time 4[s] | loss 3.67
# | epoch 342 |  iter 1 / 53 | time 4[s] | loss 3.45
# | epoch 342 |  iter 31 / 53 | time 4[s] | loss 3.56
# | epoch 343 |  iter 1 / 53 | time 4[s] | loss 3.78
# | epoch 343 |  iter 31 / 53 | time 4[s] | loss 3.43
# | epoch 344 |  iter 1 / 53 | time 4[s] | loss 3.80
# | epoch 344 |  iter 31 / 53 | time 4[s] | loss 3.59
# | epoch 345 |  iter 1 / 53 | time 4[s] | loss 3.59
# | epoch 345 |  iter 31 / 53 | time 4[s] | loss 3.74
# | epoch 346 |  iter 1 / 53 | time 4[s] | loss 3.49
# | epoch 346 |  iter 31 / 53 | time 4[s] | loss 3.68
# | epoch 347 |  iter 1 / 53 | time 4[s] | loss 3.54
# | epoch 347 |  iter 31 / 53 | time 4[s] | loss 3.62
# | epoch 348 |  iter 1 / 53 | time 4[s] | loss 3.51
# | epoch 348 |  iter 31 / 53 | time 4[s] | loss 3.54
# | epoch 349 |  iter 1 / 53 | time 4[s] | loss 3.80
# | epoch 349 |  iter 31 / 53 | time 4[s] | loss 3.66
# | epoch 350 |  iter 1 / 53 | time 4[s] | loss 3.49
# | epoch 350 |  iter 31 / 53 | time 4[s] | loss 3.56
# | epoch 351 |  iter 1 / 53 | time 4[s] | loss 3.65
# | epoch 351 |  iter 31 / 53 | time 4[s] | loss 3.67
# | epoch 352 |  iter 1 / 53 | time 5[s] | loss 3.43
# | epoch 352 |  iter 31 / 53 | time 5[s] | loss 3.70
# | epoch 353 |  iter 1 / 53 | time 5[s] | loss 3.59
# | epoch 353 |  iter 31 / 53 | time 5[s] | loss 3.52
# | epoch 354 |  iter 1 / 53 | time 5[s] | loss 3.63
# | epoch 354 |  iter 31 / 53 | time 5[s] | loss 3.76
# | epoch 355 |  iter 1 / 53 | time 5[s] | loss 3.32
# | epoch 355 |  iter 31 / 53 | time 5[s] | loss 3.55
# | epoch 356 |  iter 1 / 53 | time 5[s] | loss 3.55
# | epoch 356 |  iter 31 / 53 | time 5[s] | loss 3.65
# | epoch 357 |  iter 1 / 53 | time 5[s] | loss 3.49
# | epoch 357 |  iter 31 / 53 | time 5[s] | loss 3.46
# | epoch 358 |  iter 1 / 53 | time 5[s] | loss 3.74
# | epoch 358 |  iter 31 / 53 | time 5[s] | loss 3.67
# | epoch 359 |  iter 1 / 53 | time 5[s] | loss 3.44
# | epoch 359 |  iter 31 / 53 | time 5[s] | loss 3.54
# | epoch 360 |  iter 1 / 53 | time 5[s] | loss 3.61
# | epoch 360 |  iter 31 / 53 | time 5[s] | loss 3.43
# | epoch 361 |  iter 1 / 53 | time 5[s] | loss 3.63
# | epoch 361 |  iter 31 / 53 | time 5[s] | loss 3.71
# | epoch 362 |  iter 1 / 53 | time 5[s] | loss 3.43
# | epoch 362 |  iter 31 / 53 | time 5[s] | loss 3.46
# | epoch 363 |  iter 1 / 53 | time 5[s] | loss 3.55
# | epoch 363 |  iter 31 / 53 | time 5[s] | loss 3.34
# | epoch 364 |  iter 1 / 53 | time 5[s] | loss 3.79
# | epoch 364 |  iter 31 / 53 | time 5[s] | loss 3.46
# | epoch 365 |  iter 1 / 53 | time 5[s] | loss 3.67
# | epoch 365 |  iter 31 / 53 | time 5[s] | loss 3.43
# | epoch 366 |  iter 1 / 53 | time 5[s] | loss 3.69
# | epoch 366 |  iter 31 / 53 | time 5[s] | loss 3.58
# | epoch 367 |  iter 1 / 53 | time 5[s] | loss 3.45
# | epoch 367 |  iter 31 / 53 | time 5[s] | loss 3.63
# | epoch 368 |  iter 1 / 53 | time 5[s] | loss 3.46
# | epoch 368 |  iter 31 / 53 | time 5[s] | loss 3.60
# | epoch 369 |  iter 1 / 53 | time 5[s] | loss 3.37
# | epoch 369 |  iter 31 / 53 | time 5[s] | loss 3.61
# | epoch 370 |  iter 1 / 53 | time 5[s] | loss 3.38
# | epoch 370 |  iter 31 / 53 | time 5[s] | loss 3.63
# | epoch 371 |  iter 1 / 53 | time 5[s] | loss 3.40
# | epoch 371 |  iter 31 / 53 | time 5[s] | loss 3.57
# | epoch 372 |  iter 1 / 53 | time 5[s] | loss 3.56
# | epoch 372 |  iter 31 / 53 | time 5[s] | loss 3.85
# | epoch 373 |  iter 1 / 53 | time 5[s] | loss 3.07
# | epoch 373 |  iter 31 / 53 | time 5[s] | loss 3.58
# | epoch 374 |  iter 1 / 53 | time 5[s] | loss 3.44
# | epoch 374 |  iter 31 / 53 | time 5[s] | loss 3.67
# | epoch 375 |  iter 1 / 53 | time 5[s] | loss 3.29
# | epoch 375 |  iter 31 / 53 | time 5[s] | loss 3.49
# | epoch 376 |  iter 1 / 53 | time 5[s] | loss 3.52
# | epoch 376 |  iter 31 / 53 | time 5[s] | loss 3.53
# | epoch 377 |  iter 1 / 53 | time 5[s] | loss 3.55
# | epoch 377 |  iter 31 / 53 | time 5[s] | loss 3.58
# | epoch 378 |  iter 1 / 53 | time 5[s] | loss 3.34
# | epoch 378 |  iter 31 / 53 | time 5[s] | loss 3.35
# | epoch 379 |  iter 1 / 53 | time 5[s] | loss 3.80
# | epoch 379 |  iter 31 / 53 | time 5[s] | loss 3.59
# | epoch 380 |  iter 1 / 53 | time 5[s] | loss 3.39
# | epoch 380 |  iter 31 / 53 | time 5[s] | loss 3.47
# | epoch 381 |  iter 1 / 53 | time 5[s] | loss 3.53
# | epoch 381 |  iter 31 / 53 | time 5[s] | loss 3.35
# | epoch 382 |  iter 1 / 53 | time 5[s] | loss 3.71
# | epoch 382 |  iter 31 / 53 | time 5[s] | loss 3.55
# | epoch 383 |  iter 1 / 53 | time 5[s] | loss 3.46
# | epoch 383 |  iter 31 / 53 | time 5[s] | loss 3.52
# | epoch 384 |  iter 1 / 53 | time 5[s] | loss 3.44
# | epoch 384 |  iter 31 / 53 | time 5[s] | loss 3.63
# | epoch 385 |  iter 1 / 53 | time 5[s] | loss 3.31
# | epoch 385 |  iter 31 / 53 | time 5[s] | loss 3.48
# | epoch 386 |  iter 1 / 53 | time 5[s] | loss 3.37
# | epoch 386 |  iter 31 / 53 | time 5[s] | loss 3.52
# | epoch 387 |  iter 1 / 53 | time 5[s] | loss 3.54
# | epoch 387 |  iter 31 / 53 | time 5[s] | loss 3.31
# | epoch 388 |  iter 1 / 53 | time 5[s] | loss 3.59
# | epoch 388 |  iter 31 / 53 | time 5[s] | loss 3.29
# | epoch 389 |  iter 1 / 53 | time 5[s] | loss 3.75
# | epoch 389 |  iter 31 / 53 | time 5[s] | loss 3.54
# | epoch 390 |  iter 1 / 53 | time 5[s] | loss 3.40
# | epoch 390 |  iter 31 / 53 | time 5[s] | loss 3.46
# | epoch 391 |  iter 1 / 53 | time 5[s] | loss 3.46
# | epoch 391 |  iter 31 / 53 | time 5[s] | loss 3.28
# | epoch 392 |  iter 1 / 53 | time 5[s] | loss 3.73
# | epoch 392 |  iter 31 / 53 | time 5[s] | loss 3.74
# | epoch 393 |  iter 1 / 53 | time 5[s] | loss 3.09
# | epoch 393 |  iter 31 / 53 | time 5[s] | loss 3.63
# | epoch 394 |  iter 1 / 53 | time 5[s] | loss 3.31
# | epoch 394 |  iter 31 / 53 | time 5[s] | loss 3.45
# | epoch 395 |  iter 1 / 53 | time 5[s] | loss 3.50
# | epoch 395 |  iter 31 / 53 | time 5[s] | loss 3.32
# | epoch 396 |  iter 1 / 53 | time 5[s] | loss 3.55
# | epoch 396 |  iter 31 / 53 | time 5[s] | loss 3.55
# | epoch 397 |  iter 1 / 53 | time 5[s] | loss 3.38
# | epoch 397 |  iter 31 / 53 | time 5[s] | loss 3.39
# | epoch 398 |  iter 1 / 53 | time 5[s] | loss 3.52
# | epoch 398 |  iter 31 / 53 | time 5[s] | loss 3.29
# | epoch 399 |  iter 1 / 53 | time 5[s] | loss 3.57
# | epoch 399 |  iter 31 / 53 | time 5[s] | loss 3.45
# | epoch 400 |  iter 1 / 53 | time 5[s] | loss 3.47
# | epoch 400 |  iter 31 / 53 | time 5[s] | loss 3.46
# | epoch 401 |  iter 1 / 53 | time 5[s] | loss 3.52
# | epoch 401 |  iter 31 / 53 | time 5[s] | loss 3.51
# | epoch 402 |  iter 1 / 53 | time 5[s] | loss 3.36
# | epoch 402 |  iter 31 / 53 | time 5[s] | loss 3.34
# | epoch 403 |  iter 1 / 53 | time 5[s] | loss 3.59
# | epoch 403 |  iter 31 / 53 | time 5[s] | loss 3.34
# | epoch 404 |  iter 1 / 53 | time 5[s] | loss 3.64
# | epoch 404 |  iter 31 / 53 | time 5[s] | loss 3.39
# | epoch 405 |  iter 1 / 53 | time 5[s] | loss 3.46
# | epoch 405 |  iter 31 / 53 | time 5[s] | loss 3.46
# | epoch 406 |  iter 1 / 53 | time 5[s] | loss 3.39
# | epoch 406 |  iter 31 / 53 | time 5[s] | loss 3.34
# | epoch 407 |  iter 1 / 53 | time 5[s] | loss 3.46
# | epoch 407 |  iter 31 / 53 | time 5[s] | loss 3.38
# | epoch 408 |  iter 1 / 53 | time 5[s] | loss 3.46
# | epoch 408 |  iter 31 / 53 | time 5[s] | loss 3.56
# | epoch 409 |  iter 1 / 53 | time 5[s] | loss 3.33
# | epoch 409 |  iter 31 / 53 | time 5[s] | loss 3.36
# | epoch 410 |  iter 1 / 53 | time 5[s] | loss 3.49
# | epoch 410 |  iter 31 / 53 | time 5[s] | loss 3.56
# | epoch 411 |  iter 1 / 53 | time 5[s] | loss 3.22
# | epoch 411 |  iter 31 / 53 | time 5[s] | loss 3.41
# | epoch 412 |  iter 1 / 53 | time 5[s] | loss 3.46
# | epoch 412 |  iter 31 / 53 | time 5[s] | loss 3.42
# | epoch 413 |  iter 1 / 53 | time 5[s] | loss 3.39
# | epoch 413 |  iter 31 / 53 | time 5[s] | loss 3.43
# | epoch 414 |  iter 1 / 53 | time 5[s] | loss 3.43
# | epoch 414 |  iter 31 / 53 | time 5[s] | loss 3.30
# | epoch 415 |  iter 1 / 53 | time 5[s] | loss 3.44
# | epoch 415 |  iter 31 / 53 | time 5[s] | loss 3.49
# | epoch 416 |  iter 1 / 53 | time 5[s] | loss 3.32
# | epoch 416 |  iter 31 / 53 | time 5[s] | loss 3.34
# | epoch 417 |  iter 1 / 53 | time 5[s] | loss 3.44
# | epoch 417 |  iter 31 / 53 | time 5[s] | loss 3.49
# | epoch 418 |  iter 1 / 53 | time 5[s] | loss 3.32
# | epoch 418 |  iter 31 / 53 | time 5[s] | loss 3.48
# | epoch 419 |  iter 1 / 53 | time 5[s] | loss 3.28
# | epoch 419 |  iter 31 / 53 | time 5[s] | loss 3.36
# | epoch 420 |  iter 1 / 53 | time 5[s] | loss 3.46
# | epoch 420 |  iter 31 / 53 | time 6[s] | loss 3.45
# | epoch 421 |  iter 1 / 53 | time 6[s] | loss 3.30
# | epoch 421 |  iter 31 / 53 | time 6[s] | loss 3.33
# | epoch 422 |  iter 1 / 53 | time 6[s] | loss 3.47
# | epoch 422 |  iter 31 / 53 | time 6[s] | loss 3.47
# | epoch 423 |  iter 1 / 53 | time 6[s] | loss 3.30
# | epoch 423 |  iter 31 / 53 | time 6[s] | loss 3.12
# | epoch 424 |  iter 1 / 53 | time 6[s] | loss 3.75
# | epoch 424 |  iter 31 / 53 | time 6[s] | loss 3.47
# | epoch 425 |  iter 1 / 53 | time 6[s] | loss 3.32
# | epoch 425 |  iter 31 / 53 | time 6[s] | loss 3.41
# | epoch 426 |  iter 1 / 53 | time 6[s] | loss 3.25
# | epoch 426 |  iter 31 / 53 | time 6[s] | loss 3.43
# | epoch 427 |  iter 1 / 53 | time 6[s] | loss 3.39
# | epoch 427 |  iter 31 / 53 | time 6[s] | loss 3.44
# | epoch 428 |  iter 1 / 53 | time 6[s] | loss 3.30
# | epoch 428 |  iter 31 / 53 | time 6[s] | loss 3.33
# | epoch 429 |  iter 1 / 53 | time 6[s] | loss 3.41
# | epoch 429 |  iter 31 / 53 | time 6[s] | loss 3.22
# | epoch 430 |  iter 1 / 53 | time 6[s] | loss 3.63
# | epoch 430 |  iter 31 / 53 | time 6[s] | loss 3.38
# | epoch 431 |  iter 1 / 53 | time 6[s] | loss 3.34
# | epoch 431 |  iter 31 / 53 | time 6[s] | loss 3.29
# | epoch 432 |  iter 1 / 53 | time 6[s] | loss 3.44
# | epoch 432 |  iter 31 / 53 | time 6[s] | loss 3.42
# | epoch 433 |  iter 1 / 53 | time 6[s] | loss 3.30
# | epoch 433 |  iter 31 / 53 | time 6[s] | loss 3.41
# | epoch 434 |  iter 1 / 53 | time 6[s] | loss 3.28
# | epoch 434 |  iter 31 / 53 | time 6[s] | loss 3.56
# | epoch 435 |  iter 1 / 53 | time 6[s] | loss 3.05
# | epoch 435 |  iter 31 / 53 | time 6[s] | loss 3.32
# | epoch 436 |  iter 1 / 53 | time 6[s] | loss 3.50
# | epoch 436 |  iter 31 / 53 | time 6[s] | loss 3.10
# | epoch 437 |  iter 1 / 53 | time 6[s] | loss 3.55
# | epoch 437 |  iter 31 / 53 | time 6[s] | loss 3.48
# | epoch 438 |  iter 1 / 53 | time 6[s] | loss 3.17
# | epoch 438 |  iter 31 / 53 | time 6[s] | loss 3.38
# | epoch 439 |  iter 1 / 53 | time 6[s] | loss 3.38
# | epoch 439 |  iter 31 / 53 | time 6[s] | loss 3.28
# | epoch 440 |  iter 1 / 53 | time 6[s] | loss 3.55
# | epoch 440 |  iter 31 / 53 | time 6[s] | loss 3.28
# | epoch 441 |  iter 1 / 53 | time 6[s] | loss 3.47
# | epoch 441 |  iter 31 / 53 | time 6[s] | loss 3.42
# | epoch 442 |  iter 1 / 53 | time 6[s] | loss 3.20
# | epoch 442 |  iter 31 / 53 | time 6[s] | loss 3.39
# | epoch 443 |  iter 1 / 53 | time 6[s] | loss 3.25
# | epoch 443 |  iter 31 / 53 | time 6[s] | loss 3.34
# | epoch 444 |  iter 1 / 53 | time 6[s] | loss 3.38
# | epoch 444 |  iter 31 / 53 | time 6[s] | loss 3.45
# | epoch 445 |  iter 1 / 53 | time 6[s] | loss 3.23
# | epoch 445 |  iter 31 / 53 | time 6[s] | loss 3.33
# | epoch 446 |  iter 1 / 53 | time 6[s] | loss 3.29
# | epoch 446 |  iter 31 / 53 | time 6[s] | loss 3.39
# | epoch 447 |  iter 1 / 53 | time 6[s] | loss 3.23
# | epoch 447 |  iter 31 / 53 | time 6[s] | loss 3.32
# | epoch 448 |  iter 1 / 53 | time 6[s] | loss 3.18
# | epoch 448 |  iter 31 / 53 | time 6[s] | loss 3.02
# | epoch 449 |  iter 1 / 53 | time 6[s] | loss 3.73
# | epoch 449 |  iter 31 / 53 | time 6[s] | loss 3.21
# | epoch 450 |  iter 1 / 53 | time 6[s] | loss 3.49
# | epoch 450 |  iter 31 / 53 | time 6[s] | loss 3.09
# | epoch 451 |  iter 1 / 53 | time 6[s] | loss 3.61
# | epoch 451 |  iter 31 / 53 | time 6[s] | loss 3.34
# | epoch 452 |  iter 1 / 53 | time 6[s] | loss 3.43
# | epoch 452 |  iter 31 / 53 | time 6[s] | loss 3.49
# | epoch 453 |  iter 1 / 53 | time 6[s] | loss 2.95
# | epoch 453 |  iter 31 / 53 | time 6[s] | loss 3.23
# | epoch 454 |  iter 1 / 53 | time 6[s] | loss 3.49
# | epoch 454 |  iter 31 / 53 | time 6[s] | loss 3.32
# | epoch 455 |  iter 1 / 53 | time 6[s] | loss 3.53
# | epoch 455 |  iter 31 / 53 | time 6[s] | loss 3.24
# | epoch 456 |  iter 1 / 53 | time 6[s] | loss 3.32
# | epoch 456 |  iter 31 / 53 | time 6[s] | loss 3.23
# | epoch 457 |  iter 1 / 53 | time 6[s] | loss 3.46
# | epoch 457 |  iter 31 / 53 | time 6[s] | loss 3.31
# | epoch 458 |  iter 1 / 53 | time 6[s] | loss 3.30
# | epoch 458 |  iter 31 / 53 | time 6[s] | loss 3.38
# | epoch 459 |  iter 1 / 53 | time 6[s] | loss 3.16
# | epoch 459 |  iter 31 / 53 | time 6[s] | loss 3.27
# | epoch 460 |  iter 1 / 53 | time 6[s] | loss 3.20
# | epoch 460 |  iter 31 / 53 | time 6[s] | loss 3.33
# | epoch 461 |  iter 1 / 53 | time 6[s] | loss 3.19
# | epoch 461 |  iter 31 / 53 | time 6[s] | loss 3.20
# | epoch 462 |  iter 1 / 53 | time 6[s] | loss 3.43
# | epoch 462 |  iter 31 / 53 | time 6[s] | loss 3.24
# | epoch 463 |  iter 1 / 53 | time 6[s] | loss 3.38
# | epoch 463 |  iter 31 / 53 | time 6[s] | loss 3.17
# | epoch 464 |  iter 1 / 53 | time 6[s] | loss 3.40
# | epoch 464 |  iter 31 / 53 | time 6[s] | loss 3.06
# | epoch 465 |  iter 1 / 53 | time 6[s] | loss 3.57
# | epoch 465 |  iter 31 / 53 | time 6[s] | loss 3.43
# | epoch 466 |  iter 1 / 53 | time 6[s] | loss 3.14
# | epoch 466 |  iter 31 / 53 | time 6[s] | loss 3.31
# | epoch 467 |  iter 1 / 53 | time 6[s] | loss 3.23
# | epoch 467 |  iter 31 / 53 | time 6[s] | loss 3.28
# | epoch 468 |  iter 1 / 53 | time 6[s] | loss 3.29
# | epoch 468 |  iter 31 / 53 | time 6[s] | loss 3.23
# ...
# | epoch 914 |  iter 31 / 53 | time 13[s] | loss 2.68
# | epoch 915 |  iter 1 / 53 | time 13[s] | loss 3.11
# | epoch 915 |  iter 31 / 53 | time 13[s] | loss 2.74
# | epoch 916 |  iter 1 / 53 | time 13[s] | loss 3.15
# | epoch 916 |  iter 31 / 53 | time 13[s] | loss 3.04
# | epoch 917 |  iter 1 / 53 | time 13[s] | loss 2.60
# | epoch 917 |  iter 31 / 53 | time 13[s] | loss 2.94
# | epoch 918 |  iter 1 / 53 | time 13[s] | loss 2.81
# | epoch 918 |  iter 31 / 53 | time 13[s] | loss 2.97
# | epoch 919 |  iter 1 / 53 | time 13[s] | loss 2.69
# | epoch 919 |  iter 31 / 53 | time 13[s] | loss 3.01
# | epoch 920 |  iter 1 / 53 | time 13[s] | loss 2.81
# | epoch 920 |  iter 31 / 53 | time 13[s] | loss 2.68
# | epoch 921 |  iter 1 / 53 | time 13[s] | loss 3.09
# | epoch 921 |  iter 31 / 53 | time 13[s] | loss 3.03
# | epoch 922 |  iter 1 / 53 | time 13[s] | loss 2.70
# | epoch 922 |  iter 31 / 53 | time 13[s] | loss 2.93
# | epoch 923 |  iter 1 / 53 | time 13[s] | loss 2.69
# | epoch 923 |  iter 31 / 53 | time 13[s] | loss 2.98
# | epoch 924 |  iter 1 / 53 | time 13[s] | loss 2.80
# | epoch 924 |  iter 31 / 53 | time 13[s] | loss 2.91
# | epoch 925 |  iter 1 / 53 | time 13[s] | loss 2.94
# | epoch 925 |  iter 31 / 53 | time 13[s] | loss 3.04
# | epoch 926 |  iter 1 / 53 | time 13[s] | loss 2.65
# | epoch 926 |  iter 31 / 53 | time 13[s] | loss 3.09
# | epoch 927 |  iter 1 / 53 | time 13[s] | loss 2.70
# | epoch 927 |  iter 31 / 53 | time 13[s] | loss 2.85
# | epoch 928 |  iter 1 / 53 | time 13[s] | loss 2.89
# | epoch 928 |  iter 31 / 53 | time 13[s] | loss 2.85
# | epoch 929 |  iter 1 / 53 | time 13[s] | loss 2.89
# | epoch 929 |  iter 31 / 53 | time 13[s] | loss 3.08
# | epoch 930 |  iter 1 / 53 | time 13[s] | loss 2.52
# | epoch 930 |  iter 31 / 53 | time 13[s] | loss 2.93
# | epoch 931 |  iter 1 / 53 | time 13[s] | loss 2.86
# | epoch 931 |  iter 31 / 53 | time 13[s] | loss 2.88
# | epoch 932 |  iter 1 / 53 | time 13[s] | loss 2.88
# | epoch 932 |  iter 31 / 53 | time 13[s] | loss 2.68
# | epoch 933 |  iter 1 / 53 | time 13[s] | loss 3.20
# | epoch 933 |  iter 31 / 53 | time 13[s] | loss 2.85
# | epoch 934 |  iter 1 / 53 | time 13[s] | loss 2.86
# | epoch 934 |  iter 31 / 53 | time 13[s] | loss 2.74
# | epoch 935 |  iter 1 / 53 | time 13[s] | loss 2.94
# | epoch 935 |  iter 31 / 53 | time 13[s] | loss 3.03
# | epoch 936 |  iter 1 / 53 | time 13[s] | loss 2.71
# | epoch 936 |  iter 31 / 53 | time 13[s] | loss 2.77
# | epoch 937 |  iter 1 / 53 | time 13[s] | loss 3.00
# | epoch 937 |  iter 31 / 53 | time 13[s] | loss 2.77
# | epoch 938 |  iter 1 / 53 | time 13[s] | loss 2.95
# | epoch 938 |  iter 31 / 53 | time 13[s] | loss 2.86
# | epoch 939 |  iter 1 / 53 | time 13[s] | loss 2.90
# | epoch 939 |  iter 31 / 53 | time 13[s] | loss 2.64
# | epoch 940 |  iter 1 / 53 | time 13[s] | loss 3.22
# | epoch 940 |  iter 31 / 53 | time 13[s] | loss 2.85
# | epoch 941 |  iter 1 / 53 | time 13[s] | loss 2.88
# | epoch 941 |  iter 31 / 53 | time 13[s] | loss 2.85
# | epoch 942 |  iter 1 / 53 | time 13[s] | loss 2.92
# | epoch 942 |  iter 31 / 53 | time 13[s] | loss 3.09
# | epoch 943 |  iter 1 / 53 | time 13[s] | loss 2.54
# | epoch 943 |  iter 31 / 53 | time 13[s] | loss 2.91
# | epoch 944 |  iter 1 / 53 | time 13[s] | loss 2.97
# | epoch 944 |  iter 31 / 53 | time 13[s] | loss 2.72
# | epoch 945 |  iter 1 / 53 | time 13[s] | loss 3.00
# | epoch 945 |  iter 31 / 53 | time 13[s] | loss 2.70
# | epoch 946 |  iter 1 / 53 | time 13[s] | loss 3.27
# | epoch 946 |  iter 31 / 53 | time 13[s] | loss 2.87
# | epoch 947 |  iter 1 / 53 | time 13[s] | loss 2.78
# | epoch 947 |  iter 31 / 53 | time 13[s] | loss 2.85
# | epoch 948 |  iter 1 / 53 | time 13[s] | loss 2.92
# | epoch 948 |  iter 31 / 53 | time 13[s] | loss 2.85
# | epoch 949 |  iter 1 / 53 | time 13[s] | loss 2.88
# | epoch 949 |  iter 31 / 53 | time 13[s] | loss 2.94
# | epoch 950 |  iter 1 / 53 | time 13[s] | loss 2.88
# | epoch 950 |  iter 31 / 53 | time 13[s] | loss 2.63
# | epoch 951 |  iter 1 / 53 | time 13[s] | loss 3.04
# | epoch 951 |  iter 31 / 53 | time 13[s] | loss 2.82
# | epoch 952 |  iter 1 / 53 | time 13[s] | loss 2.98
# | epoch 952 |  iter 31 / 53 | time 13[s] | loss 2.99
# | epoch 953 |  iter 1 / 53 | time 13[s] | loss 2.74
# | epoch 953 |  iter 31 / 53 | time 13[s] | loss 2.86
# | epoch 954 |  iter 1 / 53 | time 13[s] | loss 2.89
# | epoch 954 |  iter 31 / 53 | time 13[s] | loss 2.87
# | epoch 955 |  iter 1 / 53 | time 13[s] | loss 2.98
# | epoch 955 |  iter 31 / 53 | time 13[s] | loss 2.98
# | epoch 956 |  iter 1 / 53 | time 13[s] | loss 2.66
# | epoch 956 |  iter 31 / 53 | time 13[s] | loss 2.78
# | epoch 957 |  iter 1 / 53 | time 13[s] | loss 2.95
# | epoch 957 |  iter 31 / 53 | time 13[s] | loss 2.70
# | epoch 958 |  iter 1 / 53 | time 13[s] | loss 3.11
# | epoch 958 |  iter 31 / 53 | time 13[s] | loss 2.91
# | epoch 959 |  iter 1 / 53 | time 13[s] | loss 2.79
# | epoch 959 |  iter 31 / 53 | time 13[s] | loss 2.83
# | epoch 960 |  iter 1 / 53 | time 13[s] | loss 2.98
# | epoch 960 |  iter 31 / 53 | time 13[s] | loss 2.75
# | epoch 961 |  iter 1 / 53 | time 13[s] | loss 3.00
# | epoch 961 |  iter 31 / 53 | time 13[s] | loss 2.94
# | epoch 962 |  iter 1 / 53 | time 13[s] | loss 2.78
# | epoch 962 |  iter 31 / 53 | time 13[s] | loss 2.62
# | epoch 963 |  iter 1 / 53 | time 13[s] | loss 3.13
# | epoch 963 |  iter 31 / 53 | time 13[s] | loss 2.83
# | epoch 964 |  iter 1 / 53 | time 13[s] | loss 2.85
# | epoch 964 |  iter 31 / 53 | time 13[s] | loss 2.91
# | epoch 965 |  iter 1 / 53 | time 13[s] | loss 2.86
# | epoch 965 |  iter 31 / 53 | time 13[s] | loss 2.73
# | epoch 966 |  iter 1 / 53 | time 13[s] | loss 3.14
# | epoch 966 |  iter 31 / 53 | time 13[s] | loss 2.96
# | epoch 967 |  iter 1 / 53 | time 13[s] | loss 2.68
# | epoch 967 |  iter 31 / 53 | time 13[s] | loss 2.97
# | epoch 968 |  iter 1 / 53 | time 13[s] | loss 2.78
# | epoch 968 |  iter 31 / 53 | time 13[s] | loss 2.74
# | epoch 969 |  iter 1 / 53 | time 13[s] | loss 3.13
# | epoch 969 |  iter 31 / 53 | time 13[s] | loss 2.90
# | epoch 970 |  iter 1 / 53 | time 13[s] | loss 2.71
# | epoch 970 |  iter 31 / 53 | time 13[s] | loss 3.06
# | epoch 971 |  iter 1 / 53 | time 13[s] | loss 2.60
# | epoch 971 |  iter 31 / 53 | time 13[s] | loss 2.96
# | epoch 972 |  iter 1 / 53 | time 13[s] | loss 2.74
# | epoch 972 |  iter 31 / 53 | time 13[s] | loss 2.89
# | epoch 973 |  iter 1 / 53 | time 13[s] | loss 2.83
# | epoch 973 |  iter 31 / 53 | time 13[s] | loss 2.66
# | epoch 974 |  iter 1 / 53 | time 13[s] | loss 3.14
# | epoch 974 |  iter 31 / 53 | time 14[s] | loss 2.85
# | epoch 975 |  iter 1 / 53 | time 14[s] | loss 2.96
# | epoch 975 |  iter 31 / 53 | time 14[s] | loss 2.77
# | epoch 976 |  iter 1 / 53 | time 14[s] | loss 2.90
# | epoch 976 |  iter 31 / 53 | time 14[s] | loss 2.96
# | epoch 977 |  iter 1 / 53 | time 14[s] | loss 2.70
# | epoch 977 |  iter 31 / 53 | time 14[s] | loss 3.00
# | epoch 978 |  iter 1 / 53 | time 14[s] | loss 2.74
# | epoch 978 |  iter 31 / 53 | time 14[s] | loss 2.80
# | epoch 979 |  iter 1 / 53 | time 14[s] | loss 2.95
# | epoch 979 |  iter 31 / 53 | time 14[s] | loss 2.96
# | epoch 980 |  iter 1 / 53 | time 14[s] | loss 2.71
# | epoch 980 |  iter 31 / 53 | time 14[s] | loss 2.92
# | epoch 981 |  iter 1 / 53 | time 14[s] | loss 2.82
# | epoch 981 |  iter 31 / 53 | time 14[s] | loss 2.79
# | epoch 982 |  iter 1 / 53 | time 14[s] | loss 2.94
# | epoch 982 |  iter 31 / 53 | time 14[s] | loss 2.74
# | epoch 983 |  iter 1 / 53 | time 14[s] | loss 3.08
# | epoch 983 |  iter 31 / 53 | time 14[s] | loss 2.79
# | epoch 984 |  iter 1 / 53 | time 14[s] | loss 2.90
# | epoch 984 |  iter 31 / 53 | time 14[s] | loss 3.00
# | epoch 985 |  iter 1 / 53 | time 14[s] | loss 2.65
# | epoch 985 |  iter 31 / 53 | time 14[s] | loss 2.94
# | epoch 986 |  iter 1 / 53 | time 14[s] | loss 2.80
# | epoch 986 |  iter 31 / 53 | time 14[s] | loss 2.91
# | epoch 987 |  iter 1 / 53 | time 14[s] | loss 2.71
# | epoch 987 |  iter 31 / 53 | time 14[s] | loss 2.95
# | epoch 988 |  iter 1 / 53 | time 14[s] | loss 2.76
# | epoch 988 |  iter 31 / 53 | time 14[s] | loss 2.67
# | epoch 989 |  iter 1 / 53 | time 14[s] | loss 3.12
# | epoch 989 |  iter 31 / 53 | time 14[s] | loss 2.95
# | epoch 990 |  iter 1 / 53 | time 14[s] | loss 2.71
# | epoch 990 |  iter 31 / 53 | time 14[s] | loss 2.74
# | epoch 991 |  iter 1 / 53 | time 14[s] | loss 2.99
# | epoch 991 |  iter 31 / 53 | time 14[s] | loss 2.87
# | epoch 992 |  iter 1 / 53 | time 14[s] | loss 2.87
# | epoch 992 |  iter 31 / 53 | time 14[s] | loss 2.65
# | epoch 993 |  iter 1 / 53 | time 14[s] | loss 3.05
# | epoch 993 |  iter 31 / 53 | time 14[s] | loss 2.77
# | epoch 994 |  iter 1 / 53 | time 14[s] | loss 2.99
# | epoch 994 |  iter 31 / 53 | time 14[s] | loss 2.71
# | epoch 995 |  iter 1 / 53 | time 14[s] | loss 3.00
# | epoch 995 |  iter 31 / 53 | time 14[s] | loss 2.92
# | epoch 996 |  iter 1 / 53 | time 14[s] | loss 2.78
# | epoch 996 |  iter 31 / 53 | time 14[s] | loss 2.85
# | epoch 997 |  iter 1 / 53 | time 14[s] | loss 2.96
# | epoch 997 |  iter 31 / 53 | time 14[s] | loss 2.73
# | epoch 998 |  iter 1 / 53 | time 14[s] | loss 2.96
# | epoch 998 |  iter 31 / 53 | time 14[s] | loss 2.76
# | epoch 999 |  iter 1 / 53 | time 14[s] | loss 2.94
# | epoch 999 |  iter 31 / 53 | time 14[s] | loss 2.85
# | epoch 1000 |  iter 1 / 53 | time 14[s] | loss 2.89
# | epoch 1000 |  iter 31 / 53 | time 14[s] | loss 2.80
#  [ 0.27649617  1.9580458  -5.377545    0.6725082  -4.2411346 ]
# i'm [ 0.83752555  1.2977568   0.08388761 -1.4030946  -2.524223  ]
# trying [-4.5953693  -6.4979415  -1.0715824  -5.2902956  -0.08744065]
# to [ 4.9049487  -0.97515774 -0.91764235 -0.40288112  0.6908815 ]
# import [ 2.861513   -2.1041946  -4.3364162  -0.33102447 -4.0403023 ]
# a [ 1.8580178   0.15144736 -1.0744536   0.7458273  -1.458945  ]
# couple [ 5.983705  -1.523956  -3.3069317 -3.3505752 -6.200749 ]
# .txt [ 2.7969613 -6.8565736  2.322924  -9.123548  -4.8812222]
# files [ 0.0576729  1.70464   -2.5759125 -1.6833922 -3.7054698]
# into [ 2.1893535 -2.3277767  6.61688   -5.9798803 -4.903087 ]
# colab [-3.6228344   0.61672044  0.82160807 -2.9534938  -3.0455883 ]
# from [ 3.8473396  2.918711   2.3893025 -1.1804787 -4.6044025]
# my [-3.461776   -3.8702059   0.40595958 -1.5160735  -0.77903813]
# own [ 4.593033   4.504415   1.7277535 -4.572069  -2.0438178]
# google [-4.287021   -2.041117   -0.76485664  0.96307313 -0.8953847 ]
# drive [-1.8251216   5.243295    4.9584503  -6.87699     0.06028467]
# . [-1.2287743   1.1091608  -0.12454847 -2.5968003  -1.2037915 ]
# the [ 0.8828079  -0.17472026  2.0544732  -1.589009   -0.14826897]
# notebook [ 0.46683517 -1.7268564   1.2407299  -2.8460808   0.367972  ]
# using [-0.91746134  0.63711095  0.89465946 -5.473383    6.0389047 ]
# is [-1.959397   4.456256   2.917668  -0.7299161  1.3661522]
# in [-5.4029512  5.922729  -1.5775912 -2.0737708  2.8015814]
# same [-5.812521    5.9651313   0.9323344   1.5911822   0.37157416]
# folder [ 6.3706965  1.8956264  5.281552  -6.7035823  4.786137 ]
# as [-5.7597966   5.884142    0.92435324  1.58363     0.35861346]
# i [ 1.3782836 -3.150114   3.4078248 -2.7783546  1.2301365]
# want [-2.7848127 -1.1828454 -6.3712244 -3.8594403 -3.8000405]
# upload [-0.56188977 -2.2828393   0.4816986   0.34527856 -2.492414  ]
# within [ 3.703401   -3.9707327   2.1566553   0.93516123 -0.08732323]
# that [ 0.05435404 -0.6282206   2.2864413   0.94501877 -6.164379  ]
# while [-6.271971   3.7723923  3.8102415 -4.0271335  2.7222347]
# there [-2.9263017  6.339103  -1.3109605 -4.8636765  2.2739513]
# documentation [ 0.6695622   4.176613   -0.07263637 -2.3177805   6.2081203 ]
# on [-3.1829565  2.2015245  0.7071943  2.4112375  3.2642677]
# file [-1.0270113  6.3559127  4.755606   3.2340322  6.1481037]
# i/o [-0.24308304  6.44078    -1.3050861   1.8253483   6.2770605 ]
# external [3.8100336  6.246573   4.8735123  0.39904687 4.263859  ]
# data: [-6.538948  -1.2185469  4.155247   2.2309     6.6412554]
# local [3.4604585 1.7435452 4.5248594 1.4469082 0.9131037]
# files, [-3.2407782 -5.5899897  3.1625798  4.228667   3.5063179]
# drive, [ 1.9436309   5.0958133   6.798512    5.34854    -0.09183922]
# sheets, [-0.9556479 -4.12475    1.1157223  5.596634   4.2599325]
# and [-1.5700011   0.42683572  4.866704    3.4947221   0.26377445]
# cloud [ 3.850014  -5.500931   1.7053365  3.31782    4.158028 ]
# storage [-6.9083877 -2.832649   3.2303815  6.6619534 -3.5350785]
# colab, [-6.3465867  -0.22401081 -0.13701913  2.9214642  -5.863562  ]
# descriptions [-2.3416696   6.21724    -6.00151     1.7557136   0.21421744]
# do [-1.5721346  -1.1423374   6.7886615  -0.04873018 -3.7050464 ]
# not [ 2.1995661  1.398945  -3.4839358  3.2481275  3.0773654]
# seem [-4.07415   -6.1804795  2.0774183 -1.0024748 -6.327336 ]
# fit [-0.84099317 -3.6709685   0.17122412 -6.3017416  -6.718053  ]
# what [ 2.0512102 -1.2208688  1.5692583 -5.9312816  5.755016 ]
# looking [-1.2043622 -4.439265  -2.0284588 -5.8917227  2.220513 ]
# for [ 0.82395166  1.3291177   1.0117862   0.7549135  -1.717276  ]
# (e [ 1.0531363   0.41656464 -3.9101872  -6.9434934   2.9186416 ]
# .g [-5.328787   4.537187   6.5374684 -1.8686343 -2.6037347]
# could [ 1.1795359  -1.31836    -0.49918994 -2.8216977  -0.74975044]
# these [ 4.319441  -6.5103507  4.395333  -2.2593157 -6.39973  ]
# directly [-2.1614947 -5.7959485  4.0741844 -6.8167176 -4.66888  ]
# directory [-6.3967643  -2.2275717   0.713992   -0.25197822  5.2803373 ]
# each [ 4.299775   -1.9846857   6.6876655   0.91886324  4.810941  ]
# time [-5.681209   -0.6170605  -4.3282332  -5.3866553   0.22436804]
# use [-1.798675   -0.34267786 -3.0504222  -0.9311406  -0.61083925]
# notebook, [-3.5981004  2.937944  -5.9733133 -1.0348594  1.2952323]
# but [-0.3403806 -0.5530963  6.2078047 -2.121282   6.773908 ]
# instead, [-1.1605687   2.9151747  -6.8660502  -3.6176436  -0.04921028]
# would [ 4.5049005  0.8687412 -6.172926  -6.712831  -1.1430014]
# like [-1.198702   -6.842689    0.81500024 -6.3756676  -1.300704  ]
# have [ 2.8832312  -2.1069193  -4.356842   -0.31050214 -4.0633984 ]
# cell [ 3.7361665  -0.71114945 -1.9565046   1.9238609  -6.9873705 ]
# written [ 6.631632  -6.8340635 -0.9654591  3.8285873 -1.4087962]
# loads [ 3.9037414 -6.492074  -1.5256641 -2.3320427  3.8974023]
# them [-0.32935053 -3.343223    2.5857906   5.0681987  -1.8949001 ]
# once [ 1.3726863  -1.7195811  -1.8226173   0.77506816  6.017246  ]
# keeps [ 1.3707532 -1.7184322 -1.8249359  0.7722481  6.014672 ]
# loaded [ 5.485853    2.9217649  -6.907431   -0.28045762  3.94009   ]
# via [ 4.3881764 -2.6950474 -4.9061203  5.5680513 -6.7698584]
# connection [ 2.8613145  -2.1166382  -4.3470163  -0.33097962 -4.0480347 ]
# drive) [-6.4392147 -1.6829507  5.813019  -0.7849497  1.4524091]
# also, [-6.135702   3.5679111  2.8820748 -3.9893353 -1.3141233]
# contain [ 6.8459396  -0.50877213  2.6581602   2.9974196  -6.8557024 ]
# samples [ 5.35873   -5.4809227  4.0969234  5.9955816 -2.984618 ]
# of [ 3.5584407  0.422603   3.218316   6.8276706 -6.6945324]
# plain [ 6.228121  -1.2996279  2.1318145  5.585174   2.2771857]
# text [-1.8097992 -1.0085108 -5.1409593  4.1098623 -6.608284 ]
# training [ 6.140093   -3.6827059  -6.31643    -5.63018    -0.71028817]
# deep [ 4.079222   2.9051623 -6.891952  -1.9097682 -4.531405 ]
# learning [ 3.0871994   4.92565    -0.29384652  6.76568     1.8325012 ]
# algorithm [ 4.682001   6.8659034 -2.7889242 -3.0246682  3.9717329]
# sentiment [2.123036  2.2438843 4.223444  5.3232036 6.217983 ]
# analysis, [-2.7108669e+00 -4.6817074e-03 -4.1957930e-01  5.2660570e+00
#   5.8394470e+00]
# thus [ 1.0718765 -0.9474131 -3.0502162  6.236384   5.383483 ]
# does [-6.6513424  0.6545943  6.764174   1.3209999 -3.3045187]
# appear [-4.0970793 -6.216597   2.0909922 -1.0136037 -6.3599524]
# be [ 0.8078072   0.00963317 -2.2491162  -0.5143296  -0.5436936 ]
# convertable [ 1.4901544 -6.2772236 -4.856344   2.6447875  0.3926665]
# .csv [ 4.4163094 -3.7955956 -1.5098379 -6.9740424 -0.0407657]
# functionally [-4.0620046 -6.134853  -5.270282  -2.2324865  2.9416924]
# equivalent [-4.480559    2.5049431  -2.5316362   6.7134156  -0.95877296]
# application [-5.5241275 -4.579443  -5.825438   1.9018416  3.8563437]
# (which [-0.7976948 -0.5670376 -6.6373067  3.2288868 -0.7773604]
# might [-0.83393955 -5.524588   -6.6370635   5.67738     3.7104301 ]
# solved [ 0.27257228 -6.656881   -3.9708133   5.5126357   0.96236295]
# by [ 5.4478097   5.504825   -1.064893   -6.95794     0.23033907]
# sheets) [-1.814899    5.2416987   4.961204   -6.870319    0.04664301]
